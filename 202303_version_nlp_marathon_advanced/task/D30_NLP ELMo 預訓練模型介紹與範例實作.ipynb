# %% [markdown]
# # 作業 : 調整 ELMo 模型的不同訓練參數

# %% [markdown]
# # [作業目標]
# - 調整 ELMo 模型的不同參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [參數說明]
# - UNITS : LSTM 特徵維度，即每一筆訓練輸入單字的個數
# - N_LAYERS : LSTM 堆疊的層數
# - BATCH_SIZE : 訓練批次大小，即幾筆資料合併做一次倒傳遞
# - LEARNING_RATE : 學習速率，影響收斂的快慢，須配合 BATCH_SIZE 調整

# %% [markdown]
# # [參考解答]
# - UNITS : 數值越大loss越小，但是會與計算時間成正比，且改善降幅會越來越小
# - N_LAYERS : 超過兩層以上時，影響不大
# - BATCH_SIZE : 影響收斂所需的迭代次數，也會影響最終能收斂到的 loss 下限
# - LEARNING_RATE : 配合BATCH_SIZE調整，不適當的學習速率也會影響最終收斂的下限

# %%
# [Deep contextualized word representations](https://arxiv.org/pdf/1802.05365.pdf)
from tensorflow import keras
import tensorflow as tf
import D30_utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
import os

class ELMo(keras.Model):
    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super().__init__()
        self.n_layers = n_layers
        self.units = units

        # encoder
        self.word_embed = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,  # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.001),
            mask_zero=True,
        )
        # forward lstm
        self.fs = [keras.layers.LSTM(units, return_sequences=True) for _ in range(n_layers)]
        self.f_logits = keras.layers.Dense(v_dim)
        # backward lstm
        self.bs = [keras.layers.LSTM(units, return_sequences=True, go_backwards=True) for _ in range(n_layers)]
        self.b_logits = keras.layers.Dense(v_dim)

        self.cross_entropy1 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.cross_entropy2 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.opt = keras.optimizers.Adam(lr)

    def call(self, seqs):
        embedded = self.word_embed(seqs)        # [n, step, dim]
        """
        0123    forward
        1234    forward predict
         1234   backward 
         0123   backward predict
        """
        mask = self.word_embed.compute_mask(seqs)
        fxs, bxs = [embedded[:, :-1]], [embedded[:, 1:]]
        for fl, bl in zip(self.fs, self.bs):
            fx = fl(
                fxs[-1], mask=mask[:, :-1], initial_state=fl.get_initial_state(fxs[-1])
            )           # [n, step-1, dim]
            bx = bl(
                bxs[-1], mask=mask[:, 1:], initial_state=bl.get_initial_state(bxs[-1])
            )  # [n, step-1, dim]
            fxs.append(fx)      # predict 1234
            bxs.append(tf.reverse(bx, axis=[1]))    # predict 0123
        return fxs, bxs

    def step(self, seqs):
        with tf.GradientTape() as tape:
            fxs, bxs = self.call(seqs)
            fo, bo = self.f_logits(fxs[-1]), self.b_logits(bxs[-1])
            loss = (self.cross_entropy1(seqs[:, 1:], fo) + self.cross_entropy2(seqs[:, :-1], bo))/2
        grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, (fo, bo)

    def get_emb(self, seqs):
        fxs, bxs = self.call(seqs)
        xs = [tf.concat((f[:, :-1, :], b[:, 1:, :]), axis=2).numpy() for f, b in zip(fxs, bxs)]
        for x in xs:
            print("layers shape=", x.shape)
        return xs


def train(model, data, step):
    t0 = time.time()
    for t in range(step):
        seqs = data.sample(BATCH_SIZE)
        loss, (fo, bo) = model.step(seqs)
        if t % 80 == 0:
            fp = fo[0].numpy().argmax(axis=1)
            bp = bo[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0] if i != data.pad_id]),
                "\n| f_prd: ", " ".join([data.i2v[i] for i in fp if i != data.pad_id]),
                "\n| b_prd: ", " ".join([data.i2v[i] for i in bp if i != data.pad_id]),
                )
            t0 = t1
    os.makedirs("./visual/models/elmo", exist_ok=True)
    model.save_weights("./visual/models/elmo/model.ckpt")


def export_w2v(model, data):
    model.load_weights("./visual/models/elmo/model.ckpt")
    emb = model.get_emb(data.sample(4))
    print(emb)


if __name__ == "__main__":
    D30_utils.set_soft_gpu(True)
    UNITS = 256
    N_LAYERS = 2
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    d = D30_utils.MRPCSingle("./MRPC", rows=2000)
    print("num word: ", d.num_word)
    m = ELMo(d.num_word, emb_dim=UNITS, units=UNITS, n_layers=N_LAYERS, lr=LEARNING_RATE)
    train(m, d, 10000)
    export_w2v(m, d)
# Out:
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_train.txt
# completed
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_test.txt
# completed
# num word:  12880
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# step:  0 | time: 1.02 | loss: 9.463
# | tgt:  <GO> the democratic candidates also began announcing their fund-raising totals in advance of the deadline today to file quarterly reports with the federal election commission . <SEP>
# | f_prd:  medina fed callebaut callebaut hong hong hong hong shadrin shadrin shadrin palestine palestine overwhelmingly articular articular scrambling scrambling talabani talabani antivirus checks putting mcauliffe performer performer performer performer performer performer performer performer performer performer performer performer performer
# | b_prd:  2.0ghz 2.0ghz discussed discussed discussed bunia idefense idefense idefense motorists motorists notified resources resources purveyors resources easily-manageable professor steam little midpoint lucy lucy probe excused mgm
#
#
# step:  80 | time: 61.80 | loss: 7.504
# | tgt:  <GO> two of the britons , sandy mitchell from glasgow and glasgow-born william sampson , face the death penalty . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  160 | time: 68.14 | loss: 6.873
# | tgt:  <GO> from july <NUM> , <NUM> , to june <NUM> , <NUM> , the organization said it spent $ <NUM> million but took in only $ <NUM> million . <SEP>
# | f_prd:  , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , , , , , , , , , . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  240 | time: 61.53 | loss: 6.995
# | tgt:  <GO> officials tentatively planned to burn about <NUM> acres of dense forest by dropping incendiary devices from the air , aiming to remove fuel from the wildfire 's path . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  320 | time: 60.53 | loss: 7.056
# | tgt:  <GO> overture 's listings are generated by more than <NUM> advertisers who bid for placement on keywords relevant to their business . <SEP>
# | f_prd:  the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , , . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  400 | time: 66.43 | loss: 6.951
# | tgt:  <GO> out of the nearly $ <NUM> billion , $ <NUM> billion is earmarked for reconstruction of iraq and $ <NUM> billion for afghanistan . <SEP>
# | f_prd:  the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  480 | time: 69.10 | loss: 6.995
# | tgt:  <GO> but the new study , from the women 's health initiative , said the opposite . <SEP>
# | f_prd:  the
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  560 | time: 71.11 | loss: 6.945
# | tgt:  <GO> at his request , he will be reassigned within the district . <SEP>
# | f_prd:  the the , , the , <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  640 | time: 82.38 | loss: 6.595
# | tgt:  <GO> kerkowski and fassett 's bodies were unearthed at selenski 's mount olivet road home on june <NUM> . <SEP>
# | f_prd:  the the the , , , , , the , , , , the , the , , <SEP>
# | b_prd:  the <GO> the <GO> the the the , the , the the the the <NUM> the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  720 | time: 75.04 | loss: 6.339
# | tgt:  <GO> the two had battled over custody and he allegedly told her in an angry phone call that he had no intention of following their new custody agreement . <SEP>
# | f_prd:  the the , , , the , the , , the , the , , , , the , , , , the the . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> the <GO> <GO> , , the , the , the the the the , , the the the , <NUM> the the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  800 | time: 58.89 | loss: 6.305
# | tgt:  <GO> u.s. authorities blame osama bin laden 's al-qaida network for the attacks , which killed <NUM> people , including <NUM> americans . <SEP>
# | f_prd:  the the , , the , , the , , the , , the . . . . the the . . <SEP>
# | b_prd:  <GO> <GO> the <GO> <GO> <GO> <GO> the , , the the <NUM> , the the <NUM> <NUM> <NUM> the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  880 | time: 59.70 | loss: 6.000
# | tgt:  <GO> the letter said staff was told to never speak of the incident . <SEP>
# | f_prd:  the the , the , , the the , , the said . <SEP>
# | b_prd:  <GO> the <GO> the the , , the the <NUM> in the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  960 | time: 61.91 | loss: 6.081
# | tgt:  <GO> <quote> if we don 't march into tehran , i think we will be in pretty good shape , <quote> he said . <SEP>
# | f_prd:  the the the , the the , the , the <NUM> the , the , the said . . the the . . <SEP>
# | b_prd:  <GO> <GO> the the <GO> <GO> <GO> <GO> <GO> <GO> the the , the <NUM> , the , <NUM> <NUM> <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1040 | time: 59.76 | loss: 5.862
# | tgt:  <GO> a statement from the allied command said that the raid was part of <quote> the continued effort to eradicate baath party loyalists , paramilitary groups and other subversive elements . <quote> <SEP>
# | f_prd:  the the , the <NUM> , , , the not , the , the the a the , the the the , . <quote> said , the said . . <SEP> <SEP>
# | b_prd:  <GO> the <GO> <GO> the the <GO> <GO> <GO> the <GO> the <GO> , <GO> the the , the , to <NUM> <NUM> <NUM> , , the of , <NUM> . . <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1120 | time: 57.46 | loss: 5.734
# | tgt:  <GO> morgenthau said the women , all u.s. citizens , lied on a sworn affidavit that requires them to list prior marriages . <SEP>
# | f_prd:  the said the the , the the be , the , the said the , <quote> , , the . . . <SEP>
# | b_prd:  <GO> <GO> <GO> the <GO> <GO> the the <GO> the <GO> <GO> the , , the in , the the , <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1200 | time: 57.31 | loss: 5.613
# | tgt:  <GO> amd 's chip sales jumped <NUM> percent year-on-year to $ <NUM> million . <SEP>
# | f_prd:  the , be , , <NUM> , , , <NUM> <NUM> . . <SEP>
# | b_prd:  , , the , , $ <NUM> <NUM> , $ $ <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1280 | time: 57.57 | loss: 5.638
# | tgt:  <GO> u.s. agriculture secretary ann veneman , who announced yesterday 's ban , also said washington would send a technical team to canada to assist in the canadian situation . <SEP>
# | f_prd:  the <NUM> was , been , <quote> said the , be , <quote> said in , a the <NUM> . . the . the . the statement . . <SEP>
# | b_prd:  <GO> the <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the <GO> <GO> <GO> <GO> it to , the to , in , , , in the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1360 | time: 57.57 | loss: 5.282
# | tgt:  <GO> island def jam must pay $ <NUM> million in punitive damages , and cohen must pay the remaining $ <NUM> million , the jury said . <SEP>
# | f_prd:  the said was , be the <NUM> million , the $ in the <NUM> said be the year than <NUM> million . the year . . <SEP>
# | b_prd:  <GO> to , , to to $ <NUM> , , was <NUM> , , , to in the to $ <NUM> <NUM> in and <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1440 | time: 62.91 | loss: 5.241
# | tgt:  <GO> passenger keith charlton , who also tackled the attacker , praised the efforts of the injured chief flight attendant . <SEP>
# | f_prd:  the the the , the said be the first , <quote> the first , the united , been to . <SEP>
# | b_prd:  the , <GO> said <GO> it , in the <NUM> , , , , , the and to and said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1520 | time: 57.56 | loss: 4.895
# | tgt:  <GO> in the first stage of the attack , the lovsan worm began fouling computers around the world . <SEP>
# | f_prd:  the the dow first , the first of the first first , the , , the first , <SEP>
# | b_prd:  <GO> <GO> the the he <GO> the <NUM> <GO> the , , said the , in the <NUM> .
#
#
# step:  1600 | time: 57.61 | loss: 5.118
# | tgt:  <GO> <quote> his advice to the house republicans is to pass it , to send it to him , so he can sign it . <quote> <SEP>
# | f_prd:  the we first , the first , , the be the , <quote> <NUM> the 's be to <quote> said said be the 's <SEP> <SEP>
# | b_prd:  , <GO> the , <GO> the the , , to , <NUM> , to , , , <NUM> , , and to said <NUM> . .
#
#
# step:  1680 | time: 58.87 | loss: 5.085
# | tgt:  <GO> in taiwan , officials handed out free thermometers in an island-wide ``take-your-temperature ' ' campaign amid signs containment efforts were paying off . <SEP>
# | f_prd:  the the , the , in to not in the first states , <quote> <quote> to the , not to to . . <SEP>
# | b_prd:  <GO> , <GO> <GO> , <GO> the was , of the , , , the , and and and he and be said .
#
#
# step:  1760 | time: 57.97 | loss: 4.740
# | tgt:  <GO> the nasdaq composite index increased <NUM> , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the new composite index < <NUM> points or <NUM> percent , to <NUM> percent <SEP>
# | b_prd:  <GO> nasdaq nasdaq the to $ percent , or <NUM> percent , $ said .
#
#
# step:  1840 | time: 58.35 | loss: 4.578
# | tgt:  <GO> the s. & p. <NUM> slipped <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the dow states poor 's index <NUM> points , or <NUM> percent , to <NUM> percent <SEP>
# | b_prd:  <GO> the < index $ .dji or <NUM> percent , or <NUM> percent , $ <NUM> .
#
#
# step:  1920 | time: 57.98 | loss: 4.643
# | tgt:  <GO> instead , weida decided that meester 's case on charges of rape , sodomy , indecent assault and providing alcohol to minors should proceed to a court-martial . <SEP>
# | f_prd:  the , the said in the , be , the , the , and , and and , said the to be . be to the <NUM> . <SEP>
# | b_prd:  <NUM> <GO> and has <GO> <GO> state the , on <NUM> in <NUM> , <NUM> , the , and to , and , and , in the <NUM> .
#
#
# step:  2000 | time: 58.30 | loss: 4.734
# | tgt:  <GO> after protesters rushed the stage and twice cut power to the microphone , hedges drew the speech to an early close . <SEP>
# | f_prd:  the the <NUM> the first , the the to , be company , <quote> the the company to be statement . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the , we have on , of the <NUM> , he in a according in the the <NUM> .
#
#
# step:  2080 | time: 58.54 | loss: 4.279
# | tgt:  <GO> <quote> today , we are trying to convey this problem to russian president vladimir putin ( news - web sites ) and president bush ( news - web sites ) . <quote> <SEP>
# | f_prd:  the we , the have a to be a than . be the 's have . the said said . . . the said . said . . . . . <SEP> <SEP>
# | b_prd:  <GO> <quote> <GO> <GO> it is trying to <GO> the , and , , the <NUM> the <NUM> the , , , and , <NUM> the <NUM> the the <NUM> <NUM> . .
#
#
# step:  2160 | time: 58.58 | loss: 4.323
# | tgt:  <GO> <quote> smallpox is not the only threat to the public 's health , and vaccination is not the only tool for smallpox preparedness , <quote> strom said . <SEP>
# | f_prd:  the we was not to first <NUM> to the first 's week 's <quote> he 's not to first <quote> , the 's , <quote> said said . <SEP>
# | b_prd:  <GO> <GO> it , <GO> a the <GO> in the state 's <NUM> , , , , , a the , on be percent , , <NUM> <NUM> .
#
#
# step:  2240 | time: 58.09 | loss: 4.207
# | tgt:  <GO> there are <NUM> u.s. troops in asia , most of them in south korea and japan . <SEP>
# | f_prd:  the was a years troops , the , and , the in the korea . <NUM> . <SEP>
# | b_prd:  <GO> shares least of a <NUM> in <NUM> in <NUM> for <NUM> and , , in <NUM> .
#
#
# step:  2320 | time: 58.53 | loss: 3.974
# | tgt:  <GO> mr jouejati said that with the us-backed road map <quote> in a coma <quote> the attack could easily widen through the region . <SEP>
# | f_prd:  the i said that the the united states , , , the statement , <quote> company of be <quote> . the matter . <SEP>
# | b_prd:  <quote> our , said <GO> in the the the , said in the , said the , to be <NUM> in the said .
#
#
# step:  2400 | time: 58.22 | loss: 3.917
# | tgt:  <GO> a month ago a military transport plane returned to baghdad when an engine exploded in what officials called a <quote> safety incident . <quote> <SEP>
# | f_prd:  the <NUM> , , aunt 's rejected , to the . the <NUM> york . the he said the statement . . . <SEP> <SEP>
# | b_prd:  <GO> the , <quote> the an the be , to , of a be , of , , , , the the <NUM> . .
#
#
# step:  2480 | time: 58.27 | loss: 3.816
# | tgt:  <GO> the chief merchandising officer decides what the store is going to sell , giving it a signature to attract shoppers and hopefully lure them back . <SEP>
# | f_prd:  the technology-laced jones office , the the united said the to be the <quote> the 's office to be support , situations him the . . <SEP>
# | b_prd:  <GO> the the the he of <GO> the it is need to <NUM> is said , the expected to in , and and and and said .
#
#
# step:  2560 | time: 59.22 | loss: 3.779
# | tgt:  <GO> the broader standard & poor 's <NUM> index gained <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the broader standard & poor 's <NUM> index .spx <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the broader standard & poor 's <NUM> index or <NUM> points , or <NUM> percent , to <NUM> .
#
#
# step:  2640 | time: 59.08 | loss: 3.766
# | tgt:  <GO> the rate of skin cancer has tripled since the 1950s in norway and sweden , according to the study . <SEP>
# | f_prd:  the technology-laced of the 's , been to the <NUM> . the and build . according to a u.s. . <SEP>
# | b_prd:  <GO> <NUM> <NUM> <GO> <GO> , was <NUM> in the <NUM> in <NUM> of percent , contributed in the said .
#
#
# step:  2720 | time: 58.26 | loss: 3.509
# | tgt:  <GO> however , a recent slide in prices and opec 's expectations of a surge in oil inventories have compounded its fears about a further softening of the market . <SEP>
# | f_prd:  the , the spokesman campbell in the , was 's cac-40 of the <NUM> in the america , of the operations of the statement softening of the facts . <SEP>
# | b_prd:  <GO> ago <GO> a a <GO> <GO> <GO> <GO> <GO> <GO> one <GO> the <GO> <GO> <GO> may also of and , in for a percent of stock said .
#
#
# step:  2800 | time: 59.05 | loss: 3.743
# | tgt:  <GO> mr. bush had sought to store his papers in his father 's presidential library , where they would have stayed secret for a half-century . <SEP>
# | f_prd:  the the 's not to be the first , the 23rd 's condit rights , <quote> he is be been in to the statement . <quote>
# | b_prd:  <GO> <GO> he we , has of his said of a world 's the said , that , to have be percent in a said .
#
#
# step:  2880 | time: 59.89 | loss: 3.621
# | tgt:  <GO> bush wanted <quote> to see an aircraft landing the same way that the pilots saw an aircraft landing , <quote> white house press secretary ari fleischer said yesterday . <SEP>
# | f_prd:  the said to to the the buffer 's in company county the the company 's a internet . . <quote> he secretary . . . . . . . <SEP>
# | b_prd:  <GO> we <GO> <GO> to <GO> the was <GO> the the <GO> <GO> the there <quote> the been <NUM> , the the the no , , he <NUM> said .
#
#
# step:  2960 | time: 59.21 | loss: 3.421
# | tgt:  <GO> she said the store ordered <NUM> copies and reserved another <NUM> . <SEP>
# | f_prd:  the said the company said a percent of have the week or <SEP>
# | b_prd:  <GO> , , the has to <NUM> , , of to said .
#
#
# step:  3040 | time: 61.61 | loss: 3.328
# | tgt:  <GO> the new campaign comes just weeks after u.s. appeals court rulings requiring internet service providers to identify subscribers suspected of illegally sharing music and movie files . <SEP>
# | f_prd:  the company york , a the in the the had in were be or in to be patients . . the . the and equitable files . <SEP>
# | b_prd:  <GO> the the it <GO> three <GO> <GO> <GO> the , and a and the plans to <NUM> , <NUM> <NUM> <NUM> the chairman and he said .
#
#
# step:  3120 | time: 62.62 | loss: 3.288
# | tgt:  <GO> al-amoudi was arrested at dulles international airport after arriving on a british airways flight from london . <SEP>
# | f_prd:  the said arrested in dulles international scene , the in the <NUM> court of in the . <SEP>
# | b_prd:  <GO> fine-tuning been , in dulles the , be , in a 's the <NUM> in said .
#
#
# step:  3200 | time: 61.06 | loss: 3.354
# | tgt:  <GO> <quote> during the investigation , bryant was cooperative with investigators and remains cooperative with authorities , <quote> the sheriff 's office said . <SEP>
# | f_prd:  the the the new , the 's not , the and the a , the and <quote> said 'donnell 's commissioner said . <SEP>
# | b_prd:  <GO> <GO> <GO> the <NUM> <GO> , be , with , , be <quote> , <NUM> , , 's sheriff 's he said .
#
#
# step:  3280 | time: 61.75 | loss: 3.365
# | tgt:  <GO> rumsfeld is awaiting recommendations from his commanders about troop needs in iraq . <SEP>
# | f_prd:  the was being of for the los . the care to the . <SEP>
# | b_prd:  <GO> it has the fear on the , of , <NUM> in <NUM> .
#
#
# step:  3360 | time: 61.59 | loss: 2.778
# | tgt:  <GO> the value will total about $ <NUM> million , including convertible securities , according to corel . <SEP>
# | f_prd:  the technology-laced of be <NUM> <NUM> <NUM> million , or $ first , according to the . <SEP>
# | b_prd:  <GO> the , a , to $ <NUM> <NUM> , of the percent , according to <NUM> .
#
#
# step:  3440 | time: 60.98 | loss: 2.701
# | tgt:  <GO> clearly roman creams of any type do not normally survive in the archaeological record . <SEP>
# | f_prd:  the roman creams of the county , and apply survive and the united <NUM> . <SEP>
# | b_prd:  <GO> chief 's creams , and to did not , said in a the said .
#
#
# step:  3520 | time: 62.43 | loss: 2.768
# | tgt:  <GO> when the manager let him in the apartment , brianna was in her mother 's bedroom lying in a baby 's bathtub , covered with a towel and watching cartoons . <SEP>
# | f_prd:  the the dow statement a in the united , <quote> is not the mother 's bedroom . in a single 's bathtub , <quote> with a towel and watching cartoons . <SEP>
# | b_prd:  <GO> <GO> a to on <GO> <GO> 's husband , , said <quote> her iraq the a lying in a harrison a <NUM> , , in a , and prescription said .
#
#
# step:  3600 | time: 61.78 | loss: 2.783
# | tgt:  <GO> u.s. forces organized the elections , which officials said were a step toward establishing democracy in the nation . <SEP>
# | f_prd:  the forces organized the streets , which said said that to disgrace toward establishing democracy in the united 's <SEP>
# | b_prd:  <GO> no an , the said , , , there , the boats toward establishing strangled in the said .
#
#
# step:  3680 | time: 62.58 | loss: 2.760
# | tgt:  <GO> health minister peter coleman said about <NUM> people had been killed and <NUM> wounded in the past few days . <SEP>
# | f_prd:  the vlad martin fitzgerald said it <NUM> people were been killed in the years in the region <NUM> weeks . <SEP>
# | b_prd:  of wall rev. peter , <GO> than <NUM> , has was <NUM> $ be <NUM> in the a <NUM> said .
#
#
# step:  3760 | time: 64.63 | loss: 2.880
# | tgt:  <GO> an episode is declared when the ozone reaches .20 parts per million parts of air for one hour . <SEP>
# | f_prd:  the artist was not on the euro had was was will cent in of <NUM> share <NUM> of . <SEP>
# | b_prd:  <GO> 's episode be , of of ozone reaches .20 <NUM> <NUM> juhan president the trial and an <NUM> .
#
#
# step:  3840 | time: 63.46 | loss: 2.779
# | tgt:  <GO> the ftc asked the court wednesday to block the ruling and filed for an appeal . <SEP>
# | f_prd:  the dow had the measure with morning block the ruling and to with the car . <SEP>
# | b_prd:  <GO> the has said his said attempt to of the , be , , the said .
#
#
# step:  3920 | time: 64.33 | loss: 2.355
# | tgt:  <GO> young faces a fine , suspension or being permanently barred from the securities industry . <SEP>
# | f_prd:  the of the benign of suspension or $ permanently barred for the securities and . <SEP>
# | b_prd:  <GO> he , <NUM> fine of suspension are being permanently barred in the 's said .
#
#
# step:  4000 | time: 62.07 | loss: 2.364
# | tgt:  <GO> representatives of abuse victims expressed dismay at the possibility . <SEP>
# | f_prd:  the of abuse victims expressed dismay . the united . <SEP>
# | b_prd:  <GO> representatives of abuse victims expressed dismay of the said .
#
#
# step:  4080 | time: 62.61 | loss: 2.416
# | tgt:  <GO> italian police investigating the prodi bomb suspect an anarchist group that claimed responsibility for dec. <NUM> explosions near his house , according to italian news agency ansa . <SEP>
# | f_prd:  the at investigating the prodi bomb in in anarchist group , claimed responsibility to the <NUM> explosions near his wife . according to italian news agency ansa . <SEP>
# | b_prd:  <GO> <GO> was <GO> the prodi bomb , an anarchist arrested , claimed responsibility on dec. <NUM> explosions in the rebalance , according to a the agency said .
#
#
# step:  4160 | time: 62.95 | loss: 1.963
# | tgt:  <GO> earlier this year , the company announced a restatement of its <NUM> , <NUM> and <NUM> financial results . <SEP>
# | f_prd:  the , year , which company 's a restatement of <NUM> <NUM> per <NUM> and <NUM> percent results . <SEP>
# | b_prd:  <NUM> earlier last <NUM> <GO> the also at a restatement at $ <NUM> $ <NUM> at <NUM> stock said .
#
#
# step:  4240 | time: 63.26 | loss: 2.204
# | tgt:  <GO> if draining the ponds in maryland will further help establish steve 's innocence , we welcome it . <quote> <SEP>
# | f_prd:  the the the ponds in the 's not the from into 's innocence , the welcome on . <quote> <SEP>
# | b_prd:  <GO> <GO> draining the ponds the it haven can not establish steve our innocence <quote> not welcome welcome . .
#
#
# step:  4320 | time: 63.58 | loss: 2.183
# | tgt:  <GO> <quote> we stand behind this program , <quote> said dr. william winkenwerder , assistant secretary of defense for health affairs . <SEP>
# | f_prd:  the i have to the , , <quote> said dr. young winkenwerder , assistant secretary of the , health affairs . <SEP>
# | b_prd:  <GO> <quote> we is on shuttle losses , <quote> said president william winkenwerder , assistant secretary of centre of web said .
#
#
# step:  4400 | time: 64.10 | loss: 2.458
# | tgt:  <GO> microsoft shares ( msft : news , chart , profile ) fell <NUM> cent to close at $ <NUM> . <SEP>
# | f_prd:  the 's were msft : news - chart , profile ) fell <NUM> percent to $ at $ <NUM> . <SEP>
# | b_prd:  <GO> <GO> . ( msft - chart , chart , profile index $ <NUM> percent to percent to to said .
#
#
# step:  4480 | time: 63.08 | loss: 2.081
# | tgt:  <GO> suspected rebels also blew up an oil pipeline in north-east colombia . <SEP>
# | f_prd:  the arrested officials concluded up to eyes pipeline in prison colombia . <SEP>
# | b_prd:  <GO> the , has blew dynamited 's 's <NUM> in other said .
#
#
# step:  4560 | time: 63.54 | loss: 2.248
# | tgt:  <GO> the technology-heavy nasdaq composite index gained <NUM> points , or <NUM> percent , to <NUM> , its highest close in about <NUM> months . <SEP>
# | f_prd:  the broader jones composite index was <NUM> points , or <NUM> percent , to <NUM> . following lowest close since <NUM> <NUM> . . <SEP>
# | b_prd:  <GO> the the nasdaq composite index up <NUM> points , or <NUM> percent , to <NUM> for its to million totalling $ <NUM> said .
#
#
# step:  4640 | time: 63.13 | loss: 1.871
# | tgt:  <GO> <quote> it is bad for symbian , <quote> said per lindberg , analyst at dresdner kleinwort wasserstein . <SEP>
# | f_prd:  the the 's not to the , the said dr. lindberg , analyst at dresdner kleinwort wasserstein in <SEP>
# | b_prd:  <GO> said , , intended and symbian , , <quote> a lindberg the corporation of dresdner kleinwort <NUM> .
#
#
# step:  4720 | time: 63.61 | loss: 2.108
# | tgt:  <GO> in nairobi , kenya , the very rev. peter karanja , provost of all saints cathedral , said the u.s. episcopal church <quote> is alienating itself from the anglican communion . <quote> <SEP>
# | f_prd:  the the , the , the dominican administration peter karanja , provost of the saints cathedral , said the austrian-born president church is is alienating itself from a anglican communion . <quote> <SEP>
# | b_prd:  <GO> in nairobi in kenya <GO> the the rev. peter karanja , provost of <GO> saints cathedral , of the the episcopal , , were alienating <NUM> of the anglican chip-set . .
#
#
# step:  4800 | time: 64.77 | loss: 1.944
# | tgt:  <GO> a message left with spitzer 's office as well as citigroup and goldman sachs were not immediately returned . <SEP>
# | f_prd:  the sour for a least 's office , a as a 's gromer sachs were found immediately returned to <SEP>
# | b_prd:  <GO> a hostile <GO> <GO> claritin his , as , , citigroup and music sachs were not previously <NUM> .
#
#
# step:  4880 | time: 63.88 | loss: 2.132
# | tgt:  <GO> only in the past few weeks have officials settled on the <NUM> percent figure . <SEP>
# | f_prd:  the <NUM> the first few additions on been seen during the <NUM> percent rate . <SEP>
# | b_prd:  <GO> <GO> in the a <NUM> to that observances percent of , <NUM> percent said .
#
#
# step:  4960 | time: 62.98 | loss: 1.786
# | tgt:  <GO> sco claims that the linux kernel holds unix intellectual property owned by sco . <SEP>
# | f_prd:  the has that the generic kernel holds unix intellectual property and in intentionally . <SEP>
# | b_prd:  <GO> sco decision said the an kernel holds the intellectual is war and said .
#
#
# step:  5040 | time: 63.53 | loss: 1.837
# | tgt:  <GO> plaintiffs ' attorneys would get $ <NUM> million of the settlement . <SEP>
# | f_prd:  the and ' ) be a <NUM> million in the money , <SEP>
# | b_prd:  <GO> , 's , will to $ <NUM> speak on the <NUM> .
#
#
# step:  5120 | time: 63.25 | loss: 1.891
# | tgt:  <GO> prior to joining eastman kodak , mr. palumbo held senior marketing positions for procter & gamble . <SEP>
# | f_prd:  the of joining eastman kodak , palumbo palumbo named senior marketing positions for procter & gamble . <SEP>
# | b_prd:  <GO> prior to joining eastman kodak <GO> mr. palumbo senior senior marketing positions for procter not said .
#
#
# step:  5200 | time: 64.78 | loss: 1.894
# | tgt:  <GO> there are now <NUM> active probable cases in the gta , compared with <NUM> cases on june <NUM> . <SEP>
# | f_prd:  the are the to , probable cases in the gta , compared with <NUM> percent . the <NUM> . <SEP>
# | b_prd:  <GO> there <GO> the <NUM> active probable <NUM> in the gta , compared than <NUM> concord on $ <NUM> .
#
#
# step:  5280 | time: 65.20 | loss: 1.778
# | tgt:  <GO> the house and senate are expected to vote on the omnibus bill in the next two months . <SEP>
# | f_prd:  the new of exchange products trying to be on the omnibus bill in the next two months . <SEP>
# | b_prd:  <GO> the house the he is expected a vote said the omnibus agreements in the next <NUM> said .
#
#
# step:  5360 | time: 64.06 | loss: 1.718
# | tgt:  <GO> the nasdaq composite index .ixic dipped <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the technology-laced composite index , was <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> technology-laced nasdaq composite index index up <NUM> points , or <NUM> percent , $ said .
#
#
# step:  5440 | time: 62.07 | loss: 1.684
# | tgt:  <GO> in a televised interview on wednesday , ecb president wim duisenberg said it was too soon to discuss further interest rate cuts in the <NUM>-nation euro zone . <SEP>
# | f_prd:  the the statement address that the in ecb officials wim duisenberg said it would not soon to discuss the to . cuts in the <NUM>-nation euro zone . <SEP>
# | b_prd:  <GO> in a televised <GO> on today <GO> ecb president wim duisenberg said it are too together to discuss further interest interest cuts in the the un <NUM> .
#
#
# step:  5520 | time: 61.86 | loss: 1.638
# | tgt:  <GO> the group will be headed by state department official john s. wolf , who has served in australia , vietnam , greece and pakistan . <SEP>
# | f_prd:  the broader has be in by the kevin and john s. wolf , who spoke served in the , vietnam , greece and pakistan . <SEP>
# | b_prd:  <GO> the it to be headed the the cell <GO> san s. wolf , who who vice-presidents in australia , vietnam , greece and <NUM> .
#
#
# step:  5600 | time: 63.20 | loss: 1.699
# | tgt:  <GO> selenski had previously spent seven years in prison on a bank robbery conviction . <SEP>
# | f_prd:  the had served stayed a years in prison after the bank robbery . . <SEP>
# | b_prd:  <GO> selenski , previously for <NUM> years in grew in the â new said .
#
#
# step:  5680 | time: 61.90 | loss: 1.674
# | tgt:  <GO> he resides in doha , qatar , from which russian authorities have been trying to extradite him for nearly two years . <SEP>
# | f_prd:  the said in doha , qatar , and the russian authorities had been hung to extradite him . the her years . <SEP>
# | b_prd:  <GO> yandarbiyev resides in doha , qatar said , and russian troops have is trying to extradite extradited in to <NUM> said .
#
#
# step:  5760 | time: 61.77 | loss: 1.582
# | tgt:  <GO> researchers at sweden 's karolinska institute reanalyzed data from more than <NUM> infants who had been treated with radiation for a benign birthmark condition between <NUM> and <NUM> . <SEP>
# | f_prd:  the at sweden 's karolinska institute reanalyzed data from the than <NUM> infants who had been treated with radiation for the harmless birthmark condition between <NUM> and <NUM> . <SEP>
# | b_prd:  <GO> researchers at sweden 's karolinska institute reanalyzed data charred more than <NUM> infants , had was treated of radiation for a harmless birthmark lose between <NUM> to <NUM> .
#
#
# step:  5840 | time: 61.86 | loss: 1.667
# | tgt:  <GO> from <NUM> to <NUM> , there were <NUM> reported sexual assaults at the academy . <SEP>
# | f_prd:  the <NUM> , <NUM> , <NUM> is <NUM> , <NUM> assaults at the <NUM> . <SEP>
# | b_prd:  <NUM> in , in <NUM> , there the he reported his assaults for the said .
#
#
# step:  5920 | time: 61.82 | loss: 1.657
# | tgt:  <GO> he acted as an international executive producer on who wants to be a millionaire and the weakest link . <SEP>
# | f_prd:  the said as <quote> acute card producer that the wants to be a millionaire ? the weakest link . <SEP>
# | b_prd:  <GO> he acted , an chief executive producer producer he expected to in a millionaire within the weakest said .
#
#
# step:  6000 | time: 62.91 | loss: 1.444
# | tgt:  <GO> still , changes to ie <quote> may affect a large number of existing web pages , <quote> according to the w3c 's notice . <SEP>
# | f_prd:  the , blanca to ie at the affect the letter letter of the web pages , <quote> the to the w3c 's notice . <SEP>
# | b_prd:  <GO> people that registered <quote> ie it will affect the a because of existing web <NUM> , , according in the w3c the <NUM> .
#
#
# step:  6080 | time: 61.69 | loss: 1.580
# | tgt:  <GO> the court then stayed that injunction , pending an appeal by the canadian company . <SEP>
# | f_prd:  the company was already in the , and the technical for the company hearing . <SEP>
# | b_prd:  <GO> the , who bush a aids has is a obtained in the the said .
#
#
# step:  6160 | time: 62.66 | loss: 1.643
# | tgt:  <GO> friends said frank riva worked in construction in manhattan and recently helped his son get into the construction workers union . <SEP>
# | f_prd:  the said it riva had on the <quote> manhattan and the is a son , the the reimbursement <quote> , . <SEP>
# | b_prd:  <GO> , <GO> frank riva charged of home in struggled intentionally recently when his not fought in the the the said .
#
#
# step:  6240 | time: 61.89 | loss: 1.477
# | tgt:  <GO> <quote> although some firms show bpo savings , vendors overstate their current offerings , <quote> john c. mccarthy , forrester group director , said . <SEP>
# | f_prd:  the the the firms show bpo savings , vendors overstate their current offerings , <quote> mccarthy c. mccarthy , forrester group director , said . <SEP>
# | b_prd:  <GO> <quote> although some firms show bpo savings , vendors overstate 's current offerings , , john c. mccarthy , forrester social hempleman-adams he said .
#
#
# step:  6320 | time: 62.36 | loss: 1.281
# | tgt:  <GO> it would be especially cumbersome for restaurants that change their menus daily , she said . <SEP>
# | f_prd:  the also be especially cumbersome for restaurants that change their menus daily , <quote> said . <SEP>
# | b_prd:  said it to is especially cumbersome and restaurants to change their menus percent , he said .
#
#
# step:  6400 | time: 62.30 | loss: 1.514
# | tgt:  <GO> note the subheading of this terrible parable in the <quote> american masters <quote> series , <quote> arthur miller , elia kazan and the blacklist : none without sin . <quote> <SEP>
# | f_prd:  the the subheading of the terrible parable in the united spiritual masters <quote> series , <quote> said miller , elia kazan and the blacklist : none without sin . <quote> <SEP>
# | b_prd:  decision note the subheading <GO> this terrible parable in the <quote> 's masters a series , <quote> arthur miller , elia kazan and the blacklist : none without this . .
#
#
# step:  6480 | time: 62.99 | loss: 1.347
# | tgt:  <GO> sorkin , who faces charges of conspiracy to obstruct justice and lying to a grand jury , was to have been tried separately . <SEP>
# | f_prd:  the was who was a of conspiracy to obstruct the and lying to a grand jury , while not be a tried separately . <SEP>
# | b_prd:  <GO> sorkin , who on charges of conspiracy to obstruct ears and lying of a grand <NUM> he appeared to have were tried <NUM> .
#
#
# step:  6560 | time: 62.08 | loss: 1.199
# | tgt:  <GO> barry callebaut will be able to use brach 's retail network to sell products made from its german subsidiary stollwerck , which makes chocolate products unknown to the american market . <SEP>
# | f_prd:  the callebaut will be able to use brach 's retail network and sell the made a all german subsidiary stollwerck , which makes chocolate products unknown for the bus capital . <SEP>
# | b_prd:  <GO> barry callebaut will be able to , brach 's retail threatened to wall be products of its german subsidiary stollwerck , that makes chocolate products according in the stock said .
#
#
# step:  6640 | time: 62.18 | loss: 1.368
# | tgt:  <GO> the united states finally relented during president bush 's visit to africa earlier this month . <SEP>
# | f_prd:  the company states has relented in the passed 's office to latin earlier . month . <SEP>
# | b_prd:  <GO> the united reportedly finally relented russian president bush for up past million amsterdam last said .
#
#
# step:  6720 | time: 63.96 | loss: 1.525
# | tgt:  <GO> the state previously conducted two triple executions and two double executions , a practice it says is intended to reduce stress on the prison staff . <SEP>
# | f_prd:  the dow department are in triple executions and the double executions , the source on would the an to reduce stress on the prison . . <SEP>
# | b_prd:  <GO> <GO> that previously conducted two triple executions and two double executions , billups , , , and designed to reduce stress in a prison said .
#
#
# step:  6800 | time: 62.42 | loss: 1.431
# | tgt:  <GO> georgia 's median household income dropped about <NUM> percent to $ <NUM> -- a $ <NUM> dip . <SEP>
# | f_prd:  the cannot median household income will <NUM> <NUM> percent , $ <NUM> from a $ <NUM> dip . <SEP>
# | b_prd:  <GO> utah 's median household income dropped fell <NUM> , to $ <NUM> of and $ <NUM> <NUM> .
#
#
# step:  6880 | time: 62.20 | loss: 1.272
# | tgt:  <GO> close behind was india , <NUM> percent , followed by thailand and the philippines . <SEP>
# | f_prd:  the about friday india , <NUM> percent are followed by thailand and pakistan philippines . <SEP>
# | b_prd:  the , and was india weighed <NUM> percent , served , thailand in the <NUM> .
#
#
# step:  6960 | time: 63.07 | loss: 1.006
# | tgt:  <GO> this integrates with rational purifyplus and allows developers to work in supported versions of java , visual c # and visual basic .net. <SEP>
# | f_prd:  the was with rational purifyplus and allows developers to lessen with the by of sniper , visual c # and visualbasic basic .net. <SEP>
# | b_prd:  <GO> some integrated with rational purifyplus and allows developers finish operations , supported versions in java , visual c # , visual visualbasic .
#
#
# step:  7040 | time: 62.35 | loss: 1.372
# | tgt:  <GO> there are three warships with <NUM> marines lingering off its coast . <SEP>
# | f_prd:  the are no warships with the marines lingering off the coast . <SEP>
# | b_prd:  <GO> there are <NUM> warships the the marines lingering of estrogen-progestin said .
#
#
# step:  7120 | time: 63.10 | loss: 1.216
# | tgt:  <GO> the other <NUM> people in the building , including harrison 's ex-girlfriend , were not injured , police spokesman don aaron said . <SEP>
# | f_prd:  the technology-laced version people in the building , including harrison 's ex-girlfriend , was not injured , police spokesman don aaron said . <SEP>
# | b_prd:  <GO> the other <NUM> people of the building , including harrison 's ex-girlfriend , is 's injured , police spokesman , he said .
#
#
# step:  7200 | time: 64.06 | loss: 1.344
# | tgt:  <GO> even without call center requests , companies using the handset option must have <NUM> percent of their customers using the technology by the end of <NUM> . <SEP>
# | f_prd:  the out birdie threatening requests , companies as the handset option must have <NUM> percent of the customers using the technology without the end of the . <SEP>
# | b_prd:  <GO> <GO> the the people requests recent , of the handset option must about <NUM> percent of their customers at the <NUM> by the end at <NUM> .
#
#
# step:  7280 | time: 62.72 | loss: 1.274
# | tgt:  <GO> they had published an advertisement on the internet on june <NUM> , offering the cargo for sale , he added . <SEP>
# | f_prd:  the were been an advertisement on the internet , the <NUM> , offering the cargo for sale , <quote> said . <SEP>
# | b_prd:  <GO> authorities had published an advertisement on the resign on june cancer , offering the war for <NUM> <quote> he said .
#
#
# step:  7360 | time: 63.23 | loss: 1.218
# | tgt:  <GO> u.s. forces recently apprehended some <NUM> suspected foreign militants near the syrian border and are now interrogating them . <SEP>
# | f_prd:  the forces organized apprehended three <NUM> suspected companies militants near the syrian border and was held interrogating them . <SEP>
# | b_prd:  <GO> u.s. company recently apprehended about several suspected foreign area of the syrian border they are and interrogating <NUM> .
#
#
# step:  7440 | time: 63.99 | loss: 1.225
# | tgt:  <GO> the broad standard & poors <NUM>-stock index was down <NUM> points to <NUM> . <SEP>
# | f_prd:  the company standard & poor <NUM>-stock index was down <NUM> points to <NUM> . <SEP>
# | b_prd:  <GO> the broad standard & poors composite index was down <NUM> , $ said .
#
#
# step:  7520 | time: 63.37 | loss: 1.253
# | tgt:  <GO> the atlanta olympic games attack killed one woman and injured more than <NUM> other people . <SEP>
# | f_prd:  the blue-chip olympic games attack killed that woman and injured more than <NUM> people people . <SEP>
# | b_prd:  <GO> the atlanta olympic games also and federal workers <NUM> injured more of and <NUM> <NUM> .
#
#
# step:  7600 | time: 64.62 | loss: 0.953
# | tgt:  <GO> bondholders of mirant americas generation subsequently filed suit against mirant seeking to block the exchange offer . <SEP>
# | f_prd:  the of mirant americas generation subsequently filed suit , mirant seeking to block the exchange offer . <SEP>
# | b_prd:  <GO> bondholders of mirant americas generation subsequently filed suit of mirant suit to block the takeover said .
#
#
# step:  7680 | time: 64.69 | loss: 0.980
# | tgt:  <GO> his injured co-worker , a woman , was hospitalized as well but listed in good condition , reichert said . <SEP>
# | f_prd:  the body co-worker , an small was was hospitalized as well as won in good condition at reichert said . <SEP>
# | b_prd:  <GO> a to co-worker , the <NUM> , was children as , was listed , the power the he said .
#
#
# step:  7760 | time: 62.48 | loss: 1.017
# | tgt:  <GO> business groups and border cities have raised concerns that us-visit will mean longer waits to cross borders and will hurt commerce . <SEP>
# | f_prd:  the confidence and border cities have raised concerns that us-visit will mean longer lines to have borders and will hurt commerce . <SEP>
# | b_prd:  <GO> business groups and border cities have raised concerns that us-visit will mean but waits to george borders , could cross-border said .
#
#
# step:  7840 | time: 62.19 | loss: 1.033
# | tgt:  <GO> the pcs are scattered across the united states , canada and south korea . <SEP>
# | f_prd:  the company are scattered across the united states , canada and south korea . <SEP>
# | b_prd:  <GO> the pcs are scattered in the united states , , and south <NUM> .
#
#
# step:  7920 | time: 62.04 | loss: 1.202
# | tgt:  <GO> u.s. forces organized the elections , which officials said were a step toward establishing democracy in the nation . <SEP>
# | f_prd:  the manufacturing organized the elections , which officials say were enough step toward establishing democracy in iraq front . <SEP>
# | b_prd:  <GO> u.s. press organized the said , , coleman there and a step toward establishing seat in the said .
#
#
# step:  8000 | time: 62.44 | loss: 0.999
# | tgt:  <GO> ata spokeswoman diana cronan said travel was down in may through july , and she also expects it to be down some over labor day . <SEP>
# | f_prd:  the shares diana cronan said it was down in may through july <NUM> and has was expects it to be down about over labor day . <SEP>
# | b_prd:  <GO> <GO> spokeswoman diana cronan said travel shut <GO> in up in country , , , he discussed expected to be for months over the said .
#
#
# step:  8080 | time: 61.93 | loss: 1.086
# | tgt:  <GO> appeals had kept him on death row longer than anyone else in the u.s. , ap said . <SEP>
# | f_prd:  the warned kept him to the row longer than anyone else in the federal election ap said . <SEP>
# | b_prd:  <GO> appeals is kept <NUM> the death row such to anyone else from the evening , he <NUM> .
#
#
# step:  8160 | time: 62.22 | loss: 1.236
# | tgt:  <GO> meanwhile , the global death toll approached <NUM> with more than <NUM> people sickened since the severe acute respiratory syndrome virus first appeared in southern china in november . <SEP>
# | f_prd:  the , the global attorney toll approached <NUM> with more than <NUM> people sickened since the severe acute respiratory syndrome virus first appeared in southern china in november . <SEP>
# | b_prd:  <GO> meanwhile , the global death toll approached was from more than <NUM> people sickened of the severe acute respiratory syndrome virus first appeared in southern china in <NUM> .
#
#
# step:  8240 | time: 63.36 | loss: 1.039
# | tgt:  <GO> the house government reform committee rapidly approved the legislation this morning . <SEP>
# | f_prd:  the broader version reform committee rapidly rapidly the legislation as morning . <SEP>
# | b_prd:  <GO> the in government reform has rapidly of the to wednesday said .
#
#
# step:  8320 | time: 63.20 | loss: 0.907
# | tgt:  <GO> it also named robert willumstad chief operating officer , also to take effect by jan. <NUM> , <NUM> . <SEP>
# | f_prd:  the also said robert willumstad chief operating officer , robert to be effect by jan. <NUM> , <NUM> . <SEP>
# | b_prd:  <GO> it also named robert willumstad chief operating <NUM> it expected to take effect on aug. <NUM> to said .
#
#
# step:  8400 | time: 62.31 | loss: 1.199
# | tgt:  <GO> de sole said in the results statement that group performance would improve in the second half of the year and beyond . <SEP>
# | f_prd:  the sole said , the results statement that the performance would improve in the second half of the year and beyond . <SEP>
# | b_prd:  <GO> de sole said in the a said that group performance would improve in the second end of the , and said .
#
#
# step:  8480 | time: 63.64 | loss: 0.898
# | tgt:  <GO> a sour forecast from sun microsystems inc . sunw.o put more pressure on wall street before the quarterly earnings season . <SEP>
# | f_prd:  the spokesman forecast from sun microsystems inc . sunw.o put more pressure on wall street before the quarterly earnings season . <SEP>
# | b_prd:  <GO> a sour forecast from sun microsystems inc . sunw.o put the pressure on wall <NUM> of upcoming quarterly earnings said .
#
#
# step:  8560 | time: 62.15 | loss: 1.010
# | tgt:  <GO> <quote> the woman was taken to new charing cross hospital by ambulance and her condition is critical . <SEP>
# | f_prd:  the i united 's exposed to an charing cross hospital , ambulance and his condition , critical or <SEP>
# | b_prd:  <GO> <GO> 's , was taken to when charing cross followed by ambulance before economic who in said .
#
#
# step:  8640 | time: 63.07 | loss: 1.065
# | tgt:  <GO> parson has been charged on one count of intentionally causing or attempting to cause damage to a computer . <SEP>
# | f_prd:  the faces been charged in the count of intentionally causing or attempting to cause damage to a computer . <SEP>
# | b_prd:  <GO> parson has been charged said federal count of intentionally , for attempting to cause damage than protected said .
#
#
# step:  8720 | time: 61.93 | loss: 0.931
# | tgt:  <GO> they were released to authorities after officers delivered a six-pack of dr pepper to the gunman , using a long stick to pass the soda through a door . <SEP>
# | f_prd:  the were just on the from officers delivered the six-pack of soda pepper to the gunman , saying a long stick to pass at soda through a door . <SEP>
# | b_prd:  <GO> they was released to , , officers delivered the six-pack of dr pepper to the gunman were using a long stick to on the <NUM> listeners a said .
#
#
# step:  8800 | time: 62.57 | loss: 0.921
# | tgt:  <GO> brian florence , <NUM> , died sept . <NUM> of a heart attack in alexandria , said the couple 's lawyer , maranda fritz . <SEP>
# | f_prd:  the rohrbough , a , remained sunday . <NUM> of a heart attack in alexandria , said the couple 's lawyer . maranda fritz . <SEP>
# | b_prd:  <GO> brian florence , <NUM> <GO> the sept . died to a heart attack in alexandria , on the couple 's lawyer , maranda <NUM> .
#
#
# step:  8880 | time: 62.52 | loss: 0.792
# | tgt:  <GO> in one johannesburg store , <NUM> copies have been ordered . <SEP>
# | f_prd:  the a johannesburg store , <NUM> copies have been ordered held <SEP>
# | b_prd:  <GO> <quote> one johannesburg <NUM> , <NUM> copies have been said .
#
#
# step:  8960 | time: 62.83 | loss: 0.933
# | tgt:  <GO> the suite comes complete with a word processor , spreadsheet , presentation software and other components , while continuing its tradition of utilizing an xml-based file format . <SEP>
# | f_prd:  the company comes one with a word processor , spreadsheet , presentation application and other components in and it its tradition of utilizing an xml-based file format . <SEP>
# | b_prd:  <GO> the suite to complete complete a word processor , spreadsheet , presentation putin and other components , for for a tradition of utilizing an xml file said .
#
#
# step:  9040 | time: 62.93 | loss: 0.880
# | tgt:  <GO> alhart said the governor <quote> remains hopeful that the city will continue to work with us and engage in good-faith discussions . <quote> <SEP>
# | f_prd:  the said the governor will remains hopeful that the city will continue to work with the and engage in good-faith discussions . <quote> <SEP>
# | b_prd:  <GO> alhart said the <GO> <quote> remain hopeful that the it will allowed to work of back and engage in good-faith methods . .
#
#
# step:  9120 | time: 61.99 | loss: 0.880
# | tgt:  <GO> on july <NUM> , troy is expected to be sentenced to life in prison without parole . <SEP>
# | f_prd:  the thursday <NUM> , amazon , expected to die sentenced july have in prison on parole . <SEP>
# | b_prd:  <GO> on in <NUM> <GO> autoadvice is expected would be transferred to headquartered in , and <NUM> .
#
#
# step:  9200 | time: 62.99 | loss: 0.856
# | tgt:  <GO> a second bomb , evidently carried by the other woman , did not explode ; the authorities detonated the explosives later . <SEP>
# | f_prd:  the base bomb , evidently carried by the other woman , did not explode ; the authorities detonated the explosives later . <SEP>
# | b_prd:  <GO> a second bomb , evidently carried by the other <NUM> , did not explode ; and he detonated the explosives <NUM> .
#
#
# step:  9280 | time: 61.97 | loss: 0.955
# | tgt:  <GO> she said she eventually allowed him to fix her bike while she sat in his car , and they chatted . <SEP>
# | f_prd:  the said in didn allowed him to fix her bike while she sat in his car , and he chatted . <SEP>
# | b_prd:  <GO> she said she eventually allowed allowed to fix her bike while she sat to his car , and they said .
#
#
# step:  9360 | time: 62.47 | loss: 0.842
# | tgt:  <GO> at last nights protest , demonstratorschanted <quote> tapping our phones , reading our mail , the leiu should go to jail . <quote> <SEP>
# | f_prd:  the <NUM> nights protest , demonstratorschanted <quote> tapping our phones , reading our mail , the leiu should go to jail . <quote> <SEP>
# | b_prd:  <GO> at last nights protest , demonstratorschanted <quote> tapping our phones , reading our mail , the leiu should go to scores . .
#
#
# step:  9440 | time: 62.28 | loss: 0.747
# | tgt:  <GO> the stock rose <NUM> cents to $ <NUM> yesterday in nasdaq stock market trading . <SEP>
# | f_prd:  the dow lost <NUM> cents to $ <NUM> during in nasdaq stock market trading . <SEP>
# | b_prd:  <GO> the stock rose <NUM> cents at $ <NUM> yesterday in nasdaq stock exchange <NUM> .
#
#
# step:  9520 | time: 61.90 | loss: 0.878
# | tgt:  <GO> the judge 's decision ended an <NUM>-month process that included a frenzy of last-minute negotiations between bidders and creditors during a standing-room only purchasing hearing in u.s. bankruptcy court . <SEP>
# | f_prd:  the dow already decision was an <NUM>-month process that included a frenzy of last-minute negotiations between bidders and creditors . a standing-room only purchasing hearing . the bankruptcy court . <SEP>
# | b_prd:  <GO> the iraq american decision ended an <NUM>-month process that included a frenzy of last-minute negotiations between bidders and creditors into a standing-room for purchasing hearing , her the <NUM> .
#
#
# step:  9600 | time: 61.95 | loss: 0.850
# | tgt:  <GO> early voting polls will be open from <NUM> a.m. to <NUM> p.m. sept . <NUM> and sept . <NUM> . <SEP>
# | f_prd:  the voting polls and be reassigned to <NUM> a.m. to <NUM> p.m. sept . <NUM> and sept . <NUM> . <SEP>
# | b_prd:  <GO> said voting polls will be a.m. of <NUM> a.m. at <NUM> p.m. sept by <NUM> of sept to said .
#
#
# step:  9680 | time: 62.18 | loss: 0.831
# | tgt:  <GO> our <quote> spiritual enemy , <quote> boykin continued , <quote> will only be defeated if we come against them in the name of jesus . <quote> <SEP>
# | f_prd:  the mitsui spiritual enemy , <quote> boykin continued , <quote> john only be defeated if we come against them in the name of jesus . <quote> <SEP>
# | b_prd:  <GO> a <quote> spiritual enemy <GO> <quote> boykin continued airline it will only be defeated if we come of them for the name of it . .
#
#
# step:  9760 | time: 62.29 | loss: 0.750
# | tgt:  <GO> the fighting around bunia began after neighboring uganda completed the withdrawal of its more than <NUM> soldiers from the town . <SEP>
# | f_prd:  the dow around bunia began after neighboring uganda completed the withdrawal of its more than <NUM> soldiers from the town . <SEP>
# | b_prd:  <GO> the fighting around bunia began after neighboring uganda completed the withdrawal of thousands more than <NUM> soldiers in the said .
#
#
# step:  9840 | time: 64.35 | loss: 0.658
# | tgt:  <GO> last year , the court ruled <NUM>- in an ohio case that government vouchers are constitutional if they provide parents with choices among a range of religious and secular schools . <SEP>
# | f_prd:  the year , stockwell company ruled <NUM>- after the ohio case that he vouchers are constitutional if they provide parents with choices among a range of religious and secular schools . <SEP>
# | b_prd:  <GO> last year <GO> the court ruled <GO> in an ohio of that government vouchers are constitutional <quote> they provide parents of choices among a range of religious and secular <NUM> .
#
#
# step:  9920 | time: 64.23 | loss: 0.783
# | tgt:  <GO> the u.n. troops are in congo to protect u.n. installations and personnel , and they can only fire in self defense and have been unable to stem the violence . <SEP>
# | f_prd:  the technology-laced atomic are to congo to protect the installations and personnel , and the 're best fire in self defense and said not unable to stem the violence . <SEP>
# | b_prd:  <GO> the u.n. fbi are in congo to protect of installations and personnel law that us can believed fire in self self-defense to have been unable to stem abortion-related <NUM> .
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# [array([[[ 7.36822858e-02,  4.43610251e-01,  1.52894169e-01, ...,
#          -2.42782682e-01, -2.87011594e-01, -2.58541107e-01],
#         [ 3.46556246e-01, -4.94768750e-03, -1.95736334e-01, ...,
#           3.38107795e-01, -1.10581577e-01,  3.49981219e-01],
#         [-7.08978549e-02,  1.62419140e-01, -6.27793148e-02, ...,
#           3.04758787e-01, -1.30552635e-01, -1.57215580e-01],
#         ...,
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04]],
#
#        [[ 7.36822858e-02,  4.43610251e-01,  1.52894169e-01, ...,
#           1.99142888e-01,  6.22981042e-03,  2.76188374e-01],
#         [ 1.06009275e-01, -6.29560292e-01, -1.28926933e-01, ...,
#           1.64649919e-01, -1.40750647e-01, -5.11145711e-01],
#         [-2.47783005e-01, -1.13269198e+00,  1.32035702e-01, ...,
#          -1.34247735e-01, -9.25195292e-02, -1.17081016e-01],
#         ...,
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04]],
#
#        [[ 7.36822858e-02,  4.43610251e-01,  1.52894169e-01, ...,
#           3.04758787e-01, -1.30552635e-01, -1.57215580e-01],
#         [ 4.30799415e-03,  1.26837149e-01, -7.20886141e-02, ...,
#           4.13414352e-02,  5.92477381e-01,  4.90670681e-01],
#         [ 3.33417468e-02, -8.03109348e-01,  3.49144250e-01, ...,
#           1.42610759e-01, -1.29863068e-01, -1.99509919e-01],
#         ...,
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04]],
#
#        [[ 7.36822858e-02,  4.43610251e-01,  1.52894169e-01, ...,
#          -4.11766112e-01, -2.02956572e-02,  1.75348613e-02],
#         [ 2.84023315e-01, -3.33216578e-01, -5.80191761e-02, ...,
#          -1.26699194e-01,  2.01888651e-01,  1.42425016e-01],
#         [ 2.41610572e-01,  5.86931892e-02, -6.40916765e-01, ...,
#           1.20136313e-01, -7.75545001e-01, -2.95478851e-01],
#         ...,
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04],
#         [-2.82918499e-03, -4.44888487e-04, -6.24145468e-05, ...,
#          -1.04121596e-03, -1.35275663e-03,  3.91877285e-04]]],
#       dtype=float32), array([[[-6.3566047e-01, -2.5351405e-02,  7.4283969e-01, ...,
#           8.0031466e-01,  5.2880057e-07, -5.0571680e-09],
#         [-9.5589812e-06,  7.5102842e-01,  8.9063048e-03, ...,
#           9.9999464e-01,  1.5117766e-03, -3.7544148e-16],
#         [-4.2190757e-05,  9.5651764e-01,  7.9914182e-01, ...,
#           9.9939245e-01,  9.9999213e-01, -2.2975229e-01],
#         ...,
#         [-1.4221919e-01,  8.7402123e-01,  7.6072550e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-1.4221919e-01,  8.7402123e-01,  7.6072550e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-1.4221919e-01,  8.7402123e-01,  7.6072550e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-6.3566047e-01, -2.5351405e-02,  7.4283969e-01, ...,
#           9.9998802e-01,  1.0033827e-01, -2.1881149e-12],
#         [-5.8597717e-03,  4.3678266e-04,  1.1795094e-03, ...,
#           9.9744308e-01,  7.4499694e-04, -2.8242992e-02],
#         [-9.6919960e-01,  2.6007861e-05,  9.4020879e-04, ...,
#           9.9945706e-01,  3.1142169e-09, -2.1000503e-13],
#         ...,
#         [-9.9990934e-01,  5.4442387e-02,  8.3192873e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.9990934e-01,  5.4442387e-02,  8.3192873e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.9990934e-01,  5.4442387e-02,  8.3192873e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-6.3566047e-01, -2.5351405e-02,  7.4283969e-01, ...,
#           9.9969316e-01,  9.9999809e-01, -1.3496117e-01],
#         [-9.5002633e-01,  7.5145006e-01,  9.6084356e-01, ...,
#           4.6488098e-03,  3.3508081e-15, -3.6481466e-16],
#         [-9.9351275e-01,  1.3763303e-05,  1.8689676e-09, ...,
#           9.9998832e-01,  3.4542754e-02, -3.9969309e-05],
#         ...,
#         [-9.9989420e-01,  4.0781632e-02,  6.8818903e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.9989420e-01,  4.0781632e-02,  6.8818903e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.9989420e-01,  4.0781632e-02,  6.8818903e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-6.3566047e-01, -2.5351405e-02,  7.4283969e-01, ...,
#           8.7695271e-01,  5.1077331e-16, -2.2171423e-14],
#         [-4.8320038e-05,  5.1417283e-05,  1.0115152e-05, ...,
#           9.9858946e-01,  1.8361787e-08, -1.9675264e-14],
#         [-4.9980834e-08,  5.5267918e-01,  7.5039661e-01, ...,
#           9.9999976e-01,  9.9999958e-01, -9.9998236e-01],
#         ...,
#         [-9.9986905e-01,  3.5476558e-02,  7.0497942e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.9986905e-01,  3.5476558e-02,  7.0497942e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.9986905e-01,  3.5476558e-02,  7.0497942e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32), array([[[ 2.7766217e-02,  1.7098790e-14,  8.6319129e-15, ...,
#          -2.2566810e-02, -1.8212508e-04,  3.2286611e-05],
#         [ 1.2891074e-03,  1.7571444e-14,  1.8931433e-07, ...,
#          -2.2547241e-02, -1.1256795e-04,  1.9865927e-05],
#         [ 9.9502635e-01,  6.3458782e-12,  1.7238932e-05, ...,
#          -1.1252144e-04, -1.9562768e-07,  5.2143463e-07],
#         ...,
#         [ 5.7925695e-01,  7.7206016e-01,  7.5287056e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 5.7925695e-01,  7.7206016e-01,  7.5287056e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 5.7925695e-01,  7.7206016e-01,  7.5287056e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 2.7766217e-02,  1.7098790e-14,  8.6319129e-15, ...,
#          -2.1102405e-01, -9.1532645e-05,  1.0027312e-07],
#         [ 9.6402127e-01,  2.4503448e-12,  6.6665681e-03, ...,
#          -2.1102421e-01, -1.2074980e-03,  7.2879930e-06],
#         [ 9.9505353e-01,  7.7120476e-06,  6.7696655e-03, ...,
#          -2.0355663e-01, -6.6198713e-01,  1.6690824e-04],
#         ...,
#         [ 3.4589162e-03,  7.9315996e-01,  7.6158124e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 3.4589162e-03,  7.9315996e-01,  7.6158124e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 3.4589162e-03,  7.9315996e-01,  7.6158124e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 2.7766217e-02,  1.7098790e-14,  8.6319129e-15, ...,
#          -1.3371462e-03, -8.4087164e-09,  2.0036536e-08],
#         [ 9.6390563e-01,  1.7553089e-14,  1.2023515e-14, ...,
#          -1.3240115e-03, -1.0999191e-02,  2.8475763e-03],
#         [ 9.9505353e-01,  2.0158328e-07,  7.1167678e-06, ...,
#          -1.3371526e-03, -1.7942690e-03,  3.0649430e-03],
#         ...,
#         [ 2.7255451e-02,  7.7309912e-01,  7.6150692e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 2.7255451e-02,  7.7309912e-01,  7.6150692e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 2.7255451e-02,  7.7309912e-01,  7.6150692e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 2.7766217e-02,  1.7098790e-14,  8.6319129e-15, ...,
#          -2.4884045e-03, -8.7582104e-02,  4.3195078e-07],
#         [ 9.6347272e-01,  3.5645262e-09,  7.5797063e-01, ...,
#          -2.5264423e-03, -2.2547476e-02,  7.2919215e-07],
#         [ 1.7364861e-12,  1.1094568e-05,  7.5797594e-01, ...,
#          -2.5267473e-03, -4.5984461e-07,  2.8337952e-01],
#         ...,
#         [ 3.6292762e-02,  7.6769531e-01,  7.6159072e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 3.6292762e-02,  7.6769531e-01,  7.6159072e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 3.6292762e-02,  7.6769531e-01,  7.6159072e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32)]
