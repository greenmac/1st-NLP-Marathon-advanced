# %% [markdown]
# # 作業 : 調整 ELMo 模型的不同訓練參數

# %% [markdown]
# # [作業目標]
# - 調整 ELMo 模型的不同參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [參數說明]
# - UNITS : LSTM 特徵維度，即每一筆訓練輸入單字的個數
# - N_LAYERS : LSTM 堆疊的層數
# - BATCH_SIZE : 訓練批次大小，即幾筆資料合併做一次倒傳遞
# - LEARNING_RATE : 學習速率，影響收斂的快慢，須配合 BATCH_SIZE 調整

# %% [markdown]
# # [參考解答]
# - UNITS : 數值越大loss越小，但是會與計算時間成正比，且改善降幅會越來越小
# - N_LAYERS : 超過兩層以上時，影響不大
# - BATCH_SIZE : 影響收斂所需的迭代次數，也會影響最終能收斂到的 loss 下限
# - LEARNING_RATE : 配合BATCH_SIZE調整，不適當的學習速率也會影響最終收斂的下限

# %%
# [Deep contextualized word representations](https://arxiv.org/pdf/1802.05365.pdf)
from tensorflow import keras
import tensorflow as tf
import utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
import os

class ELMo(keras.Model):
    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super().__init__()
        self.n_layers = n_layers
        self.units = units

        # encoder
        self.word_embed = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,  # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.001),
            mask_zero=True,
        )
        # forward lstm
        self.fs = [keras.layers.LSTM(units, return_sequences=True) for _ in range(n_layers)]
        self.f_logits = keras.layers.Dense(v_dim)
        # backward lstm
        self.bs = [keras.layers.LSTM(units, return_sequences=True, go_backwards=True) for _ in range(n_layers)]
        self.b_logits = keras.layers.Dense(v_dim)

        self.cross_entropy1 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.cross_entropy2 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.opt = keras.optimizers.Adam(lr)

    def call(self, seqs):
        embedded = self.word_embed(seqs)        # [n, step, dim]
        """
        0123    forward
        1234    forward predict
         1234   backward 
         0123   backward predict
        """
        mask = self.word_embed.compute_mask(seqs)
        fxs, bxs = [embedded[:, :-1]], [embedded[:, 1:]]
        for fl, bl in zip(self.fs, self.bs):
            fx = fl(
                fxs[-1], mask=mask[:, :-1], initial_state=fl.get_initial_state(fxs[-1])
            )           # [n, step-1, dim]
            bx = bl(
                bxs[-1], mask=mask[:, 1:], initial_state=bl.get_initial_state(bxs[-1])
            )  # [n, step-1, dim]
            fxs.append(fx)      # predict 1234
            bxs.append(tf.reverse(bx, axis=[1]))    # predict 0123
        return fxs, bxs

    def step(self, seqs):
        with tf.GradientTape() as tape:
            fxs, bxs = self.call(seqs)
            fo, bo = self.f_logits(fxs[-1]), self.b_logits(bxs[-1])
            loss = (self.cross_entropy1(seqs[:, 1:], fo) + self.cross_entropy2(seqs[:, :-1], bo))/2
        grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, (fo, bo)
t
    def get_emb(self, seqs):
        fxs, bxs = self.call(seqs)
        xs = [tf.concat((f[:, :-1, :], b[:, 1:, :]), axis=2).numpy() for f, b in zip(fxs, bxs)]
        for x in xs:
            print("layers shape=", x.shape)
        return xs


def train(model, data, step):
    t0 = time.time()
    for t in range(step):
        seqs = data.sample(BATCH_SIZE)
        loss, (fo, bo) = model.step(seqs)
        if t % 80 == 0:
            fp = fo[0].numpy().argmax(axis=1)
            bp = bo[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0] if i != data.pad_id]),
                "\n| f_prd: ", " ".join([data.i2v[i] for i in fp if i != data.pad_id]),
                "\n| b_prd: ", " ".join([data.i2v[i] for i in bp if i != data.pad_id]),
                )
            t0 = t1
    os.makedirs("./visual/models/elmo", exist_ok=True)
    model.save_weights("./visual/models/elmo/model.ckpt")


def export_w2v(model, data):
    model.load_weights("./visual/models/elmo/model.ckpt")
    emb = model.get_emb(data.sample(4))
    print(emb)


if __name__ == "__main__":
    utils.set_soft_gpu(True)
    UNITS = 256
    N_LAYERS = 2
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    d = utils.MRPCSingle("./MRPC", rows=2000)
    print("num word: ", d.num_word)
    m = ELMo(d.num_word, emb_dim=UNITS, units=UNITS, n_layers=N_LAYERS, lr=LEARNING_RATE)
    train(m, d, 10000)
    export_w2v(m, d)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# num word:  12880
#
#
# step:  0 | time: 1.06 | loss: 9.463
# | tgt:  <GO> it has a margin of error of plus or minus <NUM> percentage points . <SEP>
# | f_prd:  mekki shoulders mackey mackey investment involved involved brought brought <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO>
# | b_prd:  craxi craxi craxi dangers dangers dangers 'neill arrived weighted weighted conflicts quarterfinal stem dvds callebaut
#
#
# step:  80 | time: 67.17 | loss: 7.439
# | tgt:  <GO> meanwhile , the main subject of oil market debate , iraq , will not send a delegation , an issue that has rankled iraqi officials . <SEP>
# | f_prd:  the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , , , , , , , , . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  160 | time: 99.47 | loss: 7.383
# | tgt:  <GO> a <NUM>-year-old mother of two is suspected of drowning her children in a bathtub before slashing her wrists in an unsuccessful suicide attempt , police said . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  240 | time: 78.48 | loss: 7.179
# | tgt:  <GO> it also named robert willumstad chief operating officer , also to take effect by jan. <NUM> , <NUM> . <SEP>
# | f_prd:  the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  320 | time: 74.59 | loss: 7.094
# | tgt:  <GO> shares of lendingtree soared $ <NUM> , or <NUM> percent , to $ <NUM> in afternoon trading on the nasdaq stock market . <SEP>
# | f_prd:  the the the the the the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  400 | time: 77.72 | loss: 6.954
# | tgt:  <GO> ms. haque , meanwhile , was on her turquoise cellphone with the smiley faces organizing the prom . <SEP>
# | f_prd:  the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  480 | time: 112.44 | loss: 6.978
# | tgt:  <GO> a number below <NUM> suggests contraction in the manufacturing sector , while a number above that indicates expansion . <SEP>
# | f_prd:  the the the the the the the the the
# | b_prd:  <GO> <GO> <GO> the the the the the the the the the the the the the the the the . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  560 | time: 83.53 | loss: 6.474
# | tgt:  <GO> the biggest threat to order seemed to be looting and crime , including robberies by some of the prisoners freed by saddam before the war . <SEP>
# | f_prd:  the the the the the the the the the the the the . . <SEP>
# | b_prd:  <GO> the the <GO> the the <NUM> the the <NUM> the <NUM> the the the the <NUM> the the the <NUM> the <NUM> the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  640 | time: 106.86 | loss: 6.522
# | tgt:  <GO> cabrera was called up to help in left field because todd hollandsworth has not been productive . <SEP>
# | f_prd:  the , , , , , , , , , , , , <SEP>
# | b_prd:  <GO> the the , , the , the , , the the the the the , <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  720 | time: 105.51 | loss: 6.608
# | tgt:  <GO> the intel c + + compiler for platform builder for microsoft .net is available for the suggested list price of $ <NUM> and is intended for oem and system integrator use . <SEP>
# | f_prd:  the the , the , , , the , , the , , , , . . . . . . . . . . <SEP> . . <SEP>
# | b_prd:  <GO> the <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , the the the , , the the , the , , , , , the the <NUM> . <SEP> <SEP> <SEP> <SEP>
#
#
# step:  800 | time: 75.08 | loss: 6.551
# | tgt:  <GO> officials with north carolina speedway at rockingham could not be reached . <SEP>
# | f_prd:  the , the , , , the , , , , <SEP> <SEP>
# | b_prd:  , , the , the , the , the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  880 | time: 71.94 | loss: 6.738
# | tgt:  <GO> the report released monday simply says , this report does not attempt to address the complexities of this issue . <SEP>
# | f_prd:  the , , , , , the the , , , , , the , , . . <SEP> <SEP>
# | b_prd:  <GO> the the <GO> the <GO> <GO> <GO> the the the the , the in the <NUM> in the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  960 | time: 72.43 | loss: 6.292
# | tgt:  <GO> he said it was a mistake , and he reimbursed the party nearly $ <NUM> . <SEP>
# | f_prd:  the the the , , , , the the , , , , , the , <SEP>
# | b_prd:  <GO> <GO> <GO> the , the <NUM> , <NUM> the in the the in to <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1040 | time: 75.54 | loss: 6.242
# | tgt:  <GO> the vendor has added <NUM> new third-party systems and <NUM> new components to the operating system 's hardware compatibility list ( hcl ) . <SEP>
# | f_prd:  the the , , , , , , , the , , , the <NUM> , , <NUM> . . . the . . <SEP>
# | b_prd:  <GO> the <GO> the the the , <NUM> , the the the , in the , , to in the <NUM> in <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1120 | time: 78.46 | loss: 6.072
# | tgt:  <GO> some state legislators behind the bill say they remain hopeful bush will sign the legislation , though they acknowledge pressure is building on the governor to do otherwise . <SEP>
# | f_prd:  the <NUM> , <NUM> the <NUM> , <NUM> , , the , , , , , the the , , , <NUM> . the <NUM> . <NUM> . . <SEP>
# | b_prd:  <GO> the <GO> <GO> <GO> the <GO> <GO> the <GO> <GO> <GO> the <GO> the <GO> <GO> <GO> the the the the <NUM> , the , the in <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1200 | time: 75.16 | loss: 5.908
# | tgt:  <GO> <quote> it is highly conditional , faces significant regulatory delays and uncertainty , and threatens serious damage to our business . <quote> <SEP>
# | f_prd:  the the , the the , the the the , , the , the the . . . <NUM> <NUM> . <SEP>
# | b_prd:  <GO> <GO> <GO> the the <GO> the to the , , the <NUM> <NUM> to , the <NUM> , of <NUM> . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1280 | time: 97.77 | loss: 5.829
# | tgt:  <GO> the new campaign comes just weeks after u.s. appeals court rulings requiring internet service providers to identify subscribers suspected of illegally sharing music and movie files . <SEP>
# | f_prd:  the the the , , the , the the the , the the the , , the . . . the . . . the . . <SEP>
# | b_prd:  <GO> the the <GO> the <NUM> <NUM> to the the <NUM> , the the <NUM> , the <NUM> and <NUM> , in , <NUM> the , <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1360 | time: 102.70 | loss: 5.483
# | tgt:  <GO> shares of astrazeneca azn.n , europe 's second biggest drugmaker , rose <NUM> percent to close at $ <NUM> on the new york stock exchange . <SEP>
# | f_prd:  the , the , , the , the the the , the the , , the , the the , the <NUM> <NUM> . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the <GO> <GO> he $ <NUM> , to , to $ , of the the said the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1440 | time: 100.92 | loss: 5.478
# | tgt:  <GO> barrera said luster gave police a false name immediately after his arrest wednesday but later revealed his true identity . <SEP>
# | f_prd:  the , the the the , the the , the the the , , the , . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the <GO> <GO> in the , , , , , the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1520 | time: 100.42 | loss: 5.270
# | tgt:  <GO> a month ago , the commerce department said gdp grew at a <NUM> percent rate . <SEP>
# | f_prd:  the the , , the the , , , , , the the , , . <SEP>
# | b_prd:  <GO> the <NUM> <GO> <GO> the , <NUM> , , <NUM> , $ <NUM> <NUM> said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1600 | time: 123.33 | loss: 5.546
# | tgt:  <GO> university of michigan president mary sue coleman said in a statement on the university 's web site , <quote> our fundamental values haven 't changed . <SEP>
# | f_prd:  the , the , , , be , the the the , the the , the the . <quote> said the <NUM> . . . . <SEP>
# | b_prd:  the <GO> <GO> <GO> i , , <NUM> , in the , of the it the , <NUM> , , the <quote> , , the said .
#
#
# step:  1680 | time: 90.57 | loss: 5.164
# | tgt:  <GO> she was arraigned on three counts of second-degree murder and ordered held without bail in sullivan county jail . <SEP>
# | f_prd:  the said <NUM> , the , , the the , the <NUM> to the . the . . . <SEP>
# | b_prd:  <GO> , was , in <NUM> percent in the , have be <NUM> <NUM> , in , to said .
#
#
# step:  1760 | time: 95.49 | loss: 4.931
# | tgt:  <GO> the companies say their consumers want to enjoy their content , regardless of the source , across different devices and locations in the home . <SEP>
# | f_prd:  the the of the the , , the , the a the , the <NUM> of the <NUM> the , the , the year . <SEP>
# | b_prd:  <GO> the has <GO> <GO> was , , , was percent , percent in the <NUM> , , be , to , in the <NUM> .
#
#
# step:  1840 | time: 78.61 | loss: 5.136
# | tgt:  <GO> the seal will ultimately be used to identify dhs badges , vehicles , signs , sea vessels and aircraft . <SEP>
# | f_prd:  the first , <NUM> to not to the , the , <quote> . <quote> . <quote> . . the . <SEP>
# | b_prd:  <GO> <GO> it that to is , to and and <NUM> , <NUM> , <NUM> and on , a said .
#
#
# step:  1920 | time: 71.96 | loss: 4.803
# | tgt:  <GO> in march <NUM> , <NUM> percent of home broadband users connected via cable modem ; <NUM> percent used a dsl service . <SEP>
# | f_prd:  the the , , the , , the , the , , the <NUM> in the percent , . year . . <SEP>
# | b_prd:  <GO> the in percent $ <NUM> shares 's percent <NUM> , <NUM> 's <NUM> percent $ <NUM> he , <quote> the said .
#
#
# step:  2000 | time: 74.09 | loss: 4.699
# | tgt:  <GO> broomhead was assigned to 2nd squadron , 3rd armor cavalry regiment , based at fort carson . <SEP>
# | f_prd:  the , <NUM> to the <NUM> , <quote> <NUM> of . . <quote> . the . . <SEP>
# | b_prd:  <GO> , was , and and <NUM> the , on the <NUM> , , at <NUM> said .
#
#
# step:  2080 | time: 76.97 | loss: 4.838
# | tgt:  <GO> hynix ceo e.j. woo condemned the decision calling the ruling an <quote> outrageous act aimed at a hidden agenda . <quote> <SEP>
# | f_prd:  the company was the jones the united , the united of than said said and to the statement . . <SEP> <SEP>
# | b_prd:  <GO> <GO> it <GO> , of the , in the in , and to , , in the the said . .
#
#
# step:  2160 | time: 72.70 | loss: 4.869
# | tgt:  <GO> samudra claims the meeting agreed with this and fine-tuning was handed to dulmatin , a bombmaker still on the run and so-called smiling bali bomber , amrozi . <SEP>
# | f_prd:  the 's that first , to the than the , not to the , <quote> statement . . the statement in the . . . . <quote> . <SEP>
# | b_prd:  <GO> he <GO> the he , , , and he , , to <NUM> is a be , to a authority a a the the <NUM> in said .
#
#
# step:  2240 | time: 70.54 | loss: 4.646
# | tgt:  <GO> <quote> it indicates we are starting the epidemic with more cases than last year , <quote> gerberding said . <SEP>
# | f_prd:  the i said that was not to first of the than , the first . <quote> said , . <SEP>
# | b_prd:  <GO> said he <quote> he , in the , and a more , this <NUM> , <quote> he said .
#
#
# step:  2320 | time: 73.17 | loss: 4.307
# | tgt:  <GO> shaklee spokeswoman jenifer thompson referred all calls to the fbi . <SEP>
# | f_prd:  the <NUM> of than was to the to the statement . <SEP>
# | b_prd:  <GO> <GO> , , and , , according in the said .
#
#
# step:  2400 | time: 73.70 | loss: 4.278
# | tgt:  <GO> <quote> that doesn 't mean to say it doesn 't exist , <quote> mr. chandler said , but simply that his team has found no such evidence . <SEP>
# | f_prd:  the the the 't be , the <NUM> , 't be , <quote> he the said , <quote> he the the first of been in be the . <SEP>
# | b_prd:  <GO> <quote> <quote> don 't <quote> 't <quote> <quote> don 't said , <quote> mr he said , are said said 's , and to and 's said .
#
#
# step:  2480 | time: 76.32 | loss: 3.912
# | tgt:  <GO> <quote> we don 't know at this point if the current investigation includes one or more outside contractors . <SEP>
# | f_prd:  the the is 't be the the than to the company states of the , the than the . <SEP>
# | b_prd:  <GO> <GO> we haven not <GO> <GO> the said of the the , to , and have the <NUM> .
#
#
# step:  2560 | time: 70.63 | loss: 4.148
# | tgt:  <GO> <quote> those rating present business conditions as ' bad ' increased to <NUM> per cent from <NUM> per cent , <quote> the report said . <SEP>
# | f_prd:  the i said 't the , , the i not is to be percent cent , the percent cent of the said year of . <SEP>
# | b_prd:  <GO> <GO> the has a 's , <NUM> , <NUM> , , or <NUM> per , or <NUM> per <NUM> , , the he said .
#
#
# step:  2640 | time: 75.02 | loss: 4.697
# | tgt:  <GO> last year , bush appointed him to the homeland security advisory council . <SEP>
# | f_prd:  the company , the was to to the <NUM> quarter , than . <SEP>
# | b_prd:  , last <NUM> that has to according to the the the the <NUM> .
#
#
# step:  2720 | time: 73.82 | loss: 4.194
# | tgt:  <GO> <quote> what this allows us to do is have a crossover that is much more fuel efficient and aimed at young families . <quote> <SEP>
# | f_prd:  the the the company the the <NUM> <NUM> a to week the the a in than . . <quote> to the . . <SEP> <SEP>
# | b_prd:  <GO> <quote> <quote> i of , we we to to and said it to to for , , said , and for said . .
#
#
# step:  2800 | time: 82.99 | loss: 4.124
# | tgt:  <GO> of all personal vehicles , <NUM> percent are cars or station wagons , <NUM> percent are vans or sport utility vehicles and <NUM> percent are light trucks . <SEP>
# | f_prd:  the the <NUM> company , the , , been of <NUM> 's , or percent , been . <NUM> share share . <NUM> percent . been . . <SEP>
# | b_prd:  shares <GO> the personal <NUM> , <NUM> , , , ( <NUM> <NUM> , <NUM> , , , and sport , <NUM> , <NUM> , , , said .
#
#
# step:  2880 | time: 100.39 | loss: 3.952
# | tgt:  <GO> the results will be published the july <NUM> issue of the journal nature . <SEP>
# | f_prd:  the dow of be been the year that , , the year of of <SEP>
# | b_prd:  <GO> the it will is in the the the percent , the stock said .
#
#
# step:  2960 | time: 72.31 | loss: 3.884
# | tgt:  <GO> when the manager let him in the apartment , brianna was in her mother 's bedroom lying in a baby 's bathtub , covered with a towel and watching cartoons . <SEP>
# | f_prd:  the the company of the to the united , <quote> said not the <NUM> 's year , to the statement 's cost , <quote> to the statement . the . . <SEP>
# | b_prd:  <GO> <GO> the to <GO> <GO> in the men , he said in the nation a the said in a baby a bathtub , , in a <NUM> and of said .
#
#
# step:  3040 | time: 68.87 | loss: 3.684
# | tgt:  <GO> cardenas and estrada , who is on trial for economic plunder , have denied any involvement . <SEP>
# | f_prd:  the , the , the was not the of the . , <quote> not . . . <SEP>
# | b_prd:  <GO> , <GO> loved , he , of , and bowel lawyer may , of 's said .
#
#
# step:  3120 | time: 70.57 | loss: 3.807
# | tgt:  <GO> the supreme court said monday the government can require public libraries to equip computers with anti-pornography filters , rejecting librarians ' complaints that the law amounts to censorship . <SEP>
# | f_prd:  the dow standard of that in year was be the , to be years in the years , <quote> said said have in the company . . the . <SEP>
# | b_prd:  <GO> <GO> the he on <GO> the i an the two is to potent charged of michael java , , <quote> southeastern said to and two , to said .
#
#
# step:  3200 | time: 72.42 | loss: 3.740
# | tgt:  <GO> a catholic priest said two miners were killed and nine other protesters injured <NUM> kilometres outside la paz as a convoy of miners threw dynamite at soldiers manning a roadblock . <SEP>
# | f_prd:  the technology-laced nasdaq was the than are 't in the years than , in percent and a . . the wife of the . . . the . a week . <SEP>
# | b_prd:  , the the , <GO> the miners been , to and a a $ <NUM> have , la , in a versions and who be , their , in a <NUM> .
#
#
# step:  3280 | time: 72.18 | loss: 3.772
# | tgt:  <GO> in vienna , the iaea said elbaradei would accept the invitation , although no date had yet been set . <SEP>
# | f_prd:  the the , the company said in would be a first , the the year of been been a . <SEP>
# | b_prd:  <GO> in statement <GO> the he said it have in the invitation , that and it not have be said .
#
#
# step:  3360 | time: 79.68 | loss: 3.642
# | tgt:  <GO> according to the report , average life expectancy has increased by nearly two years since <NUM> . <SEP>
# | f_prd:  the to the first of the were were , been to the <NUM> years , the . <SEP>
# | b_prd:  , according of the <NUM> and the the , , , to to <NUM> percent $ said .
#
#
# step:  3440 | time: 72.44 | loss: 3.507
# | tgt:  <GO> <quote> apec leaders are painfully aware that security and prosperity are inseparable , <quote> thaksin said . <SEP>
# | f_prd:  the the , are a a the the , other and been , <quote> said said . <SEP>
# | b_prd:  <GO> <quote> apec who is painfully aware homeland manner and , be percent , <quote> he said .
#
#
# step:  3520 | time: 73.64 | loss: 3.391
# | tgt:  <GO> the technology-laced nasdaq composite index < .ixic > tacked on <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the dow nasdaq composite index < .ixic > was <NUM> <NUM> , , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite index < .ixic > <NUM> down <NUM> points , or <NUM> percent , in said .
#
#
# step:  3600 | time: 73.68 | loss: 2.962
# | tgt:  <GO> a federal magistrate in fort lauderdale ordered him held without bail . <SEP>
# | f_prd:  the dow standard in the angeles , a to to the . <SEP>
# | b_prd:  , a his , , mr and to be business <NUM> said .
#
#
# step:  3680 | time: 70.13 | loss: 3.132
# | tgt:  <GO> smithfield shares rose more than <NUM> per cent yesterday as the company said it expected the transaction to boost earnings immediately . <SEP>
# | f_prd:  the was of <NUM> than <NUM> percent cent , to the nasdaq , the was to new , $ up . . <SEP>
# | b_prd:  <GO> <GO> smithfield rose more about <NUM> per grabbed percent , the , said had to the , to boost be <NUM> .
#
#
# step:  3760 | time: 70.62 | loss: 3.159
# | tgt:  <GO> tyco later said the loan had not been forgiven , and swartz repaid it in full , with interest , according to his lawyer , charles stillman . <SEP>
# | f_prd:  the said , the company was been a a , <quote> <NUM> stillman that was the of <quote> the , <quote> to the murder , <quote> stillman . <SEP>
# | b_prd:  <GO> <quote> <quote> <quote> the it had have be forgiven , <quote> fully repaid pace in <NUM> , our <NUM> , according of 's <NUM> , charles <NUM> .
#
#
# step:  3840 | time: 71.56 | loss: 2.890
# | tgt:  <GO> under the agreement , solutia will pay $ <NUM> million and monsanto will pay $ <NUM> million . <SEP>
# | f_prd:  the the <NUM> , the was be a <NUM> million , <NUM> 's be a <NUM> million . <SEP>
# | b_prd:  <GO> <GO> the lee , solutia will of $ <NUM> , and monsanto will to $ <NUM> said .
#
#
# step:  3920 | time: 72.51 | loss: 2.880
# | tgt:  <GO> the new variation of blaster was identified wednesday , according to antivirus company sophos . <SEP>
# | f_prd:  the company york of the is found in , <quote> to the , and . <SEP>
# | b_prd:  <GO> the new variation of blaster was on <NUM> , according , the <NUM> said .
#
#
# step:  4000 | time: 69.59 | loss: 2.852
# | tgt:  <GO> the company is working with the objectweb consortium , apache software foundation and the eclipse ide development community as part of the effort . <SEP>
# | f_prd:  the company is a in the state chamber , the than 's in the company of the of than the of the world of <SEP>
# | b_prd:  <GO> the , is charged of the boutique botswana , apache missiles credibility and the racial their as such as out in 's said .
#
#
# step:  4080 | time: 73.30 | loss: 2.616
# | tgt:  <GO> still others cite the difficulty of assembling a group of subjects whose depression is of comparable severity , increasing the chances that the effectiveness of the medication will be diffused . <SEP>
# | f_prd:  the the cite the united of the the statement of the the other , a the severity , <quote> the united that the mudslide of the united and be prohibited . <SEP>
# | b_prd:  <GO> <GO> others cite the difficulty in assembling the university of subjects whose depression accused of comparable severity , increasing the chances of the effectiveness of the medication to be said .
#
#
# step:  4160 | time: 71.70 | loss: 2.879
# | tgt:  <GO> dr mark mcclean , jonathan 's family doctor , said if the drug had been administered earlier jonathan would have retained more of his brain functions . <SEP>
# | f_prd:  the kenny are , the has company has , was the the company administration been administered in , or be retained the than the brain . . <SEP>
# | b_prd:  <GO> <GO> said mcclean the family a her <NUM> , <GO> of and he has chief administered , it should have retained part of 's <NUM> said .
#
#
# step:  4240 | time: 72.33 | loss: 2.959
# | tgt:  <GO> <quote> microsoft had absolutely nothing to do with atstake 's internal personnel decision , <quote> sundwall said . <SEP>
# | f_prd:  the we 's not adult , accepting a the 's say-so the of , <quote> said said . <SEP>
# | b_prd:  <GO> <quote> it had absolutely nothing to , with atstake 's internal personnel long-lived , <quote> he said .
#
#
# step:  4320 | time: 72.71 | loss: 2.741
# | tgt:  <GO> brand-name drugs in canada tend to be cheaper than in the united states because of government price controls and a favorable exchange rate . <SEP>
# | f_prd:  the , in the , to be an than <NUM> the united states , were the and were and a favorable states . . <SEP>
# | b_prd:  <GO> brand-name <GO> and it tend to be cheaper cheaper in the united <quote> meaning the of price , by a favorable death said .
#
#
# step:  4400 | time: 75.53 | loss: 2.356
# | tgt:  <GO> the foreign office said heaton was in saudi detention but had not been charged , and that consul officials had visited him on thursday . <SEP>
# | f_prd:  the dow minister is the was a the activity in was not be reached with <quote> the he officials said been a . the . <SEP>
# | b_prd:  <GO> the american , <GO> heaton said in in , ban has has been <NUM> , denied and consul , have visited said on said .
#
#
# step:  4480 | time: 74.26 | loss: 2.724
# | tgt:  <GO> massachusetts has no state death penalty , and only once before -- in michigan -- has the federal death penalty been given in a state without capital punishment . <SEP>
# | f_prd:  the has been immediate , penalty of which the $ $ the the the , has been first death penalty of given in the <NUM> . capital punishment . <SEP>
# | b_prd:  <GO> there has the the death <NUM> , and from percent percent friday in <NUM> which at the the death have , said in a state the lymphoma said .
#
#
# step:  4560 | time: 74.83 | loss: 2.675
# | tgt:  <GO> the pentagon insists the technique has successfully predicted elections and even box office receipts . <SEP>
# | f_prd:  the dow has the first was been been to and a as than in . <SEP>
# | b_prd:  <GO> the pentagon said the technique has was the , and county 's maranda said .
#
#
# step:  4640 | time: 82.17 | loss: 2.730
# | tgt:  <GO> the global epidemic of hiv , the virus that causes aids , is tightening its grip on britain with a record number of new cases diagnosed last year . <SEP>
# | f_prd:  the technology-laced dow was the , the company was the officials , was charged the first on the and the first of of the york of by week . <SEP>
# | b_prd:  <GO> the the prisoners of hiv , the <GO> , causes <NUM> it is with their garner in , of the the because a the <NUM> quarter last said .
#
#
# step:  4720 | time: 92.02 | loss: 2.485
# | tgt:  <GO> he faces an additional <NUM> years in prison on the federal charges when he is sentenced july <NUM> . <SEP>
# | f_prd:  the was a annulment <NUM> , , the and the <NUM> disaster of <NUM> was a to <NUM> . <SEP>
# | b_prd:  <GO> who in an to <NUM> years in prison of in <NUM> , where , had on $ said .
#
#
# step:  4800 | time: 78.72 | loss: 2.404
# | tgt:  <GO> jacob has pushed consolidation for years but said it has been opposed by many communities , especially rural ones . <SEP>
# | f_prd:  the has also consolidation for the and will it would not set that the communities , especially rural ones , <SEP>
# | b_prd:  <GO> jacob has pushed consolidation two , , that , have been went , <NUM> communities , and manned <NUM> .
#
#
# step:  4880 | time: 80.53 | loss: 2.267
# | tgt:  <GO> the seventh person charged in the case - habis abdu al saoub - remains at large . <SEP>
# | f_prd:  the dow & that with the state of habis abdu the saoub , <NUM> by the . <SEP>
# | b_prd:  <GO> the seventh was suspect of the news and habis abdu al saoub , , at <NUM> .
#
#
# step:  4960 | time: 97.31 | loss: 2.034
# | tgt:  <GO> on april <NUM> , mayor bart peterson said it was <quote> inconceivable <quote> that the airline would resume operations at the base that had employed <NUM> workers , including <NUM> mechanics . <SEP>
# | f_prd:  the the <NUM> , <NUM> bart the said the was no inconceivable that was he tech-laden was be levels in the united , he not the percent and <quote> the . . <SEP>
# | b_prd:  <GO> on , <NUM> , <GO> <GO> , <GO> it <GO> that inconceivable said that the people to resume , in a said he has employed fort percent , than the <NUM> .
#
#
# step:  5040 | time: 83.38 | loss: 2.393
# | tgt:  <GO> it would now take place some time before august <NUM> in auckland . <SEP>
# | f_prd:  the was be him him to of that the , and auckland . <SEP>
# | b_prd:  <GO> it would would of of the percent of to <NUM> in said .
#
#
# step:  5120 | time: 82.01 | loss: 2.271
# | tgt:  <GO> wittig resigned in late november about two weeks after being indicted on bank fraud charges in a real estate case unrelated to the company . <SEP>
# | f_prd:  the said , the <NUM> , <NUM> years , the indicted on the gathered , , the wife estate of . to shoot first . <SEP>
# | b_prd:  <GO> wittig <GO> in between <GO> to two , is being indicted the a fraud said for a the a said damage of the said .
#
#
# step:  5200 | time: 79.87 | loss: 1.996
# | tgt:  <GO> <quote> we have declared war on sexual assault and sexual harassment , <quote> rosa said . <SEP>
# | f_prd:  the the are been the to the , , harassed harassment and and he said . <SEP>
# | b_prd:  <GO> <quote> we will the spoke and indecent harassment and our long-lived , , he said .
#
#
# step:  5280 | time: 84.63 | loss: 2.190
# | tgt:  <GO> close also questions whether it would be worth the cost of licensing third-party software , along with salesforce.com 's rental price . <SEP>
# | f_prd:  the on the the the would be in to year of licensing edwards 's , who with salesforce.com 's rental punishment . <SEP>
# | b_prd:  <GO> has <GO> wondered said package would administration on the shares of the third-party share , along with salesforce.com 's rental said .
#
#
# step:  5360 | time: 77.81 | loss: 2.195
# | tgt:  <GO> most of those on board were lebanese but some were from benin , guinea and sierra leone . <SEP>
# | f_prd:  the of the who the , lebanese , the have not the , guinea and sierra leone . <SEP>
# | b_prd:  , instead told , the resign as , but people area from benin , guinea and sierra <NUM> .
#
#
# step:  5440 | time: 86.86 | loss: 1.718
# | tgt:  <GO> shares of astrazeneca azn.n , europe 's second biggest drugmaker , rose <NUM> percent to close at $ <NUM> on the new york stock exchange . <SEP>
# | f_prd:  the of mony azn.n , <NUM> , shares biggest drugmaker , rose <NUM> percent , $ at $ <NUM> , the nasdaq york stock exchange . <SEP>
# | b_prd:  <GO> shares of astrazeneca azn.n , shares 's the the <NUM> shares up <NUM> cents to , at $ <NUM> on the new york stock said .
#
#
# step:  5520 | time: 82.86 | loss: 2.135
# | tgt:  <GO> sea 05d is the naval sea systems command â s technical authority for surface ship design and engineering . <SEP>
# | f_prd:  the 05d is the naval sea , inc and s technical authority to the of , and engineering . <SEP>
# | b_prd:  <GO> jessica 05d is the naval sea systems command â a technical authority for surface , design and <NUM> .
#
#
# step:  5600 | time: 85.45 | loss: 1.978
# | tgt:  <GO> more than <NUM> people rallied over three days , proclaiming that genetically modified foods weren 't the answer to the world 's food problems . <SEP>
# | f_prd:  the than <NUM> people inside <NUM> <NUM> yearly , proclaiming that genetically modified foods weren 't have answer to the answer 's westside problems . <SEP>
# | b_prd:  <GO> more than <NUM> that rallied in <NUM> moved , proclaiming that genetically modified foods weren to the answer of the world 's evangelism said .
#
#
# step:  5680 | time: 85.33 | loss: 1.846
# | tgt:  <GO> wal-mart shares rose <NUM> cents to close at $ <NUM> on the new york stock exchange . <SEP>
# | f_prd:  the said rose <NUM> cents , $ at $ <NUM> on the new york stock exchange . <SEP>
# | b_prd:  <GO> wal-mart shares up <NUM> cents to close at $ <NUM> on the new york stock said .
#
#
# step:  5760 | time: 81.50 | loss: 1.931
# | tgt:  <GO> now the rest is just mechanical , <quote> said allan hoffenblum , a republican consultant . <SEP>
# | f_prd:  the , decision were to a , <quote> said dr. hoffenblum , a spokesman consultant . <SEP>
# | b_prd:  <GO> <GO> the aircraft were just mechanical , <quote> said allan hoffenblum , a republican <NUM> .
#
#
# step:  5840 | time: 83.45 | loss: 2.105
# | tgt:  <GO> he has declined to comment on the charges , but court documents show that a lingering medical condition could contribute to his defense . <SEP>
# | f_prd:  the said been to be on the charges to but he documents show on he lingering medical charges , be to the medical . <SEP>
# | b_prd:  <GO> it has declined to comment on the strip , the in documents argued and a lingering medical , , according of of said .
#
#
# step:  5920 | time: 73.01 | loss: 1.931
# | tgt:  <GO> but he added that de niro is <quote> a private person and doesn 't care to have his treatment out for public consumption . <quote> <SEP>
# | f_prd:  the he was that the niro is a a deal motive and the 't know to the a divisive for of the consumption . <quote> <SEP>
# | b_prd:  <GO> <GO> he <quote> of de producer , <quote> a private , and doesn its attempt to of <quote> treatment out for public mirror . .
#
#
# step:  6000 | time: 74.86 | loss: 1.758
# | tgt:  <GO> between july <NUM> , <NUM> and june <NUM> , <NUM> , the red cross spent $ <NUM> million on disaster relief , while taking in only $ <NUM> million . <SEP>
# | f_prd:  the <NUM> <NUM> , <NUM> , <NUM> <NUM> , <NUM> , <NUM> dow respiratory 's $ <NUM> million , the relief , and the the the $ <NUM> million . <SEP>
# | b_prd:  <GO> on july <NUM> , <NUM> on june <NUM> june <NUM> , the red cross of $ <NUM> activity on disaster relief , , billion the to $ <NUM> <NUM> .
#
#
# step:  6080 | time: 71.03 | loss: 1.713
# | tgt:  <GO> according to the census bureau , the hispanic population increased by <NUM> percent from the april <NUM> census figures . <SEP>
# | f_prd:  the to the muslim , , the hispanic population was by the percent from <NUM> census <NUM> census . . <SEP>
# | b_prd:  <GO> according of the the <NUM> , the hispanic <NUM> up up <NUM> percent of the the the available <NUM> .
#
#
# step:  6160 | time: 73.29 | loss: 1.832
# | tgt:  <GO> the greenback rose steeply against the euro , yen and swiss franc despite weaker-than-expected september u.s. retail sales figures . <SEP>
# | f_prd:  the technology-laced was <NUM> at the yen , up and swiss franc despite weaker-than-expected u.s. <NUM> sales sales . . <SEP>
# | b_prd:  <GO> the greenback rose steeply against the euro , yen and swiss franc by weaker-than-expected through u.s. retail census said .
#
#
# step:  6240 | time: 66.45 | loss: 1.979
# | tgt:  <GO> slow-moving , drenching tropical storm henri doused an already soaked florida on friday , pushing heavy rains into areas where lakes and rivers were full to overflowing . <SEP>
# | f_prd:  the , drenching tropical storm henri doused a oil soaked oil in the , pushing the rains from a of lakes and rivers were legally . overflowing . <SEP>
# | b_prd:  <GO> slow-moving , drenching tropical storm henri doused an already soaked killed on <NUM> , pushing heavy rains into , and lakes and there from going to said .
#
#
# step:  6320 | time: 66.70 | loss: 1.600
# | tgt:  <GO> the dow jones industrial average was up <NUM> points to <NUM> , while the nasdaq composite index fell <NUM> points to <NUM> . <SEP>
# | f_prd:  the technology-laced jones industrial average .dji up <NUM> per , <NUM> , while the nasdaq composite index was <NUM> points , <NUM> . <SEP>
# | b_prd:  <GO> the dow jones industrial average was declined <NUM> <NUM> at <NUM> , , the nasdaq composite index slipped <NUM> , at <NUM> .
#
#
# step:  6400 | time: 65.77 | loss: 1.874
# | tgt:  <GO> claudia gonzles herrera , an assistant attorney general in charge of the case , said the arrests show that guatemala <quote> takes the defense of its ancient maya heritage seriously . <quote> <SEP>
# | f_prd:  the wenders herrera , a assistant attorney-general , phil the , the first of <quote> the arrests is that guatemala <quote> said a possibility of the ancient maya heritage . . <quote> <SEP>
# | b_prd:  <GO> claudia gonzles herrera , an british <GO> attorney-general the one of the airlines , said the administration <quote> that guatemala , said the some of its ancient maya no methods . .
#
#
# step:  6480 | time: 68.73 | loss: 1.777
# | tgt:  <GO> the official , who spoke on condition of anonymity , said that two iraqis and two saudis detained after the attack gave information leading to the arrest of the others . <SEP>
# | f_prd:  the technology-laced has the was to the of the , and the it software and the saudis on in the manner , it on the lebo name . the war . <SEP>
# | b_prd:  <GO> the veneman <GO> he <GO> first two of anonymity she found to two , 's two saudis shortly when the blast of information mission in the part of and <NUM> .
#
#
# step:  6560 | time: 67.73 | loss: 1.569
# | tgt:  <GO> but he added : <quote> you can 't win elections by looking in the rearview mirror . <quote> <SEP>
# | f_prd:  the the was : <quote> i 're 't win elections with looking to the rearview mirror . <quote> <SEP>
# | b_prd:  <GO> <quote> he added : <quote> you can 't win elections are looking in the rearview beethoven . .
#
#
# step:  6640 | time: 65.56 | loss: 1.712
# | tgt:  <GO> the intel c + + compiler for platform builder for microsoft .net is available for the suggested list price of $ <NUM> and is intended for oem and system integrator use . <SEP>
# | f_prd:  the technology-laced administration + + compiler for the builder for the 's and in for the united network of of the <NUM> million of intended to the and russian integrator use . <SEP>
# | b_prd:  <GO> <GO> intel c + + compiler for platform builder <GO> of .net is available in the an a list includes $ <NUM> and is intended for oem the system personal said .
#
#
# step:  6720 | time: 65.44 | loss: 1.689
# | tgt:  <GO> but for more than a century , an untold amount of money intended for some of the nation 's poorest residents was lost , stolen or never collected . <SEP>
# | f_prd:  the ms the than <NUM> tarot , the untold amount of the intended for the of the nation 's poorest president are <quote> to stolen or never collected . <SEP>
# | b_prd:  <GO> <GO> for more than a century , an untold amount and being intended , some of the nation any poorest who was ethel , stolen or never said .
#
#
# step:  6800 | time: 70.55 | loss: 1.552
# | tgt:  <GO> nearly <NUM> mta drivers and train operators joined the mechanics in the picket line . <SEP>
# | f_prd:  the <NUM> mta drivers and train operators have for mechanics in the picket line . <SEP>
# | b_prd:  <GO> nearly <NUM> mta drivers and train operators joined the slaves in the the <NUM> .
#
#
# step:  6880 | time: 71.99 | loss: 1.526
# | tgt:  <GO> later in the day , a standoff developed between french soldiers and a hema battlewagon that attempted to pass the un compound . <SEP>
# | f_prd:  the this the united , the <NUM>-year-old developed the the soldiers and the hema battlewagon that attempted to pass the un compound . <SEP>
# | b_prd:  hours <GO> on the thursday , a standoff soldiers between french soldiers and a hema battlewagon that attempted to pass the un said .
#
#
# step:  6960 | time: 67.50 | loss: 1.677
# | tgt:  <GO> a pamphlet will be issued to the public through major hardware chains , local libraries and on the epa web site : www.epa.gov. <SEP>
# | f_prd:  the spokesman will be headed to the united 's the hardware chains , and libraries and the the epa web site , www.epa.gov. <SEP>
# | b_prd:  <GO> a pamphlet will companies linked on the distributed of major hardware chains and local libraries available to the epa web site : .
#
#
# step:  7040 | time: 69.07 | loss: 1.602
# | tgt:  <GO> microsoft shares ( msft : news , chart , profile ) fell <NUM> cent to close at $ <NUM> . <SEP>
# | f_prd:  the 's on msft : <NUM> , chart , profile ) fell <NUM> percent to close at $ <NUM> . <SEP>
# | b_prd:  <GO> <GO> back ( msft : news , chart , profile index to per percent to close to to <NUM> .
#
#
# step:  7120 | time: 72.55 | loss: 1.598
# | tgt:  <GO> no one has been killed in the attacks , which have continued despite major setbacks for al qaeda in a battle with saudi security forces . <SEP>
# | f_prd:  the dates of been killed in the crash , which has continued despite enough setbacks for human qaeda in saudi <NUM> for saudi security forces . <SEP>
# | b_prd:  <GO> no one has been killed for the attacks , which have continued despite their setbacks for al bed in a battles with saudi security said .
#
#
# step:  7200 | time: 70.07 | loss: 1.688
# | tgt:  <GO> on thursday , a post article argued that a <NUM> basis point cut from the fed was more likely . <SEP>
# | f_prd:  the jan. , the post article argued that the <NUM>-basis-point percent barrels from , the fed was in likely to <SEP>
# | b_prd:  <GO> on thursday , the post article argued to a <NUM> basis been party of the fed or more said .
#
#
# step:  7280 | time: 66.43 | loss: 1.264
# | tgt:  <GO> sco has also alleged that the generic linux kernel contains code which is from its unix property . <SEP>
# | f_prd:  the surrendered a alleged that the generic linux kernel contains code which is running the unix property . <SEP>
# | b_prd:  <GO> sco also the alleged that the generic linux kernel contains code which prevented of its unix <NUM> .
#
#
# step:  7360 | time: 85.35 | loss: 1.222
# | tgt:  <GO> helicopters hovered throughout the day over the al-khalidiya neighborhood where the raid took place . <SEP>
# | f_prd:  the hovered him the al-khalidiya after the al-khalidiya neighborhood to the raid said as . <SEP>
# | b_prd:  <GO> helicopters hovered throughout the take in the al-khalidiya neighborhood in the raid right <NUM> .
#
#
# step:  7440 | time: 69.93 | loss: 1.490
# | tgt:  <GO> the institute 's national manufacturing barometer slipped to <NUM> in september from <NUM> in august . <SEP>
# | f_prd:  the technology-laced for supply manufacturing barometer force <NUM> <NUM> in <NUM> <NUM> <NUM> in december . <SEP>
# | b_prd:  <GO> the institute 's national manufacturing plentiful rose to <NUM> in <NUM> from expires in said .
#
#
# step:  7520 | time: 80.76 | loss: 1.487
# | tgt:  <GO> north korea has demanded one-to-one talks with the united states . <SEP>
# | f_prd:  the american has demanded one-to-one talks with the united states . <SEP>
# | b_prd:  <GO> north korea has demanded one-to-one talks in the united said .
#
#
# step:  7600 | time: 79.77 | loss: 1.331
# | tgt:  <GO> the technology-laced nasdaq composite index rose <NUM> points , or <NUM> percent , to <NUM> , according to the latest available data . <SEP>
# | f_prd:  the technology-laced nasdaq composite index < <NUM> points , or <NUM> percent , to <NUM> . based to a latest available . . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite .dji gained <NUM> points , or <NUM> percent , to bank , according on the latest latest said .
#
#
# step:  7680 | time: 72.23 | loss: 1.442
# | tgt:  <GO> lee peterson testified that he reached his son on his cell phone and talked to him for a couple of minutes . <SEP>
# | f_prd:  the said is the the was the son of the car phone and talked to the to a domestic of minutes . <SEP>
# | b_prd:  asked lee lee said said he reached their decides in a cell money they respond to license by the obstruction the said .
#
#
# step:  7760 | time: 73.87 | loss: 1.252
# | tgt:  <GO> the company will offer songs for <NUM> cents and albums for $ <NUM> . <SEP>
# | f_prd:  the company is be songs for the cents per albums for $ <NUM> . <SEP>
# | b_prd:  <GO> the it a offer up of <NUM> turkey and <NUM> to $ <NUM> .
#
#
# step:  7840 | time: 75.04 | loss: 1.408
# | tgt:  <GO> <quote> i think the longer the series goes , the more chance dirk has to play , <quote> nelson said . <SEP>
# | f_prd:  the we think it strategic pass attacks of , <quote> company chance dirk has to be , <quote> said said . <SEP>
# | b_prd:  <GO> <quote> i think the longer the series goes like the the chance dirk not to enough , <quote> he said .
#
#
# step:  7920 | time: 71.78 | loss: 1.169
# | tgt:  <GO> the verbal flareup with keating stemmed from cardinal mahony 's initial refusal to participate in that survey unless procedures were changed . <SEP>
# | f_prd:  the technology-laced flareup with keating volume to cardinal mahony shamil legislation refusal to participate in the survey unless procedures were changed . <SEP>
# | b_prd:  <GO> the verbal flareup with keating stemmed and cardinal mahony a initial refusal to participate before that survey unless procedures 't said .
#
#
# step:  8000 | time: 69.63 | loss: 1.283
# | tgt:  <GO> mr hadley , who has a new partner and child , said : <quote> i am absolutely delighted . <SEP>
# | f_prd:  the kenny , who has enjoyed only loss of the , who the <quote> the am absolutely delighted . <SEP>
# | b_prd:  <GO> mr hadley , who <GO> a global , of . hadley saying : <quote> i am absolutely said .
#
#
# step:  8080 | time: 67.54 | loss: 1.316
# | tgt:  <GO> emergency crews said some of the passengers were thrown partly out of the open side of the bus . <SEP>
# | f_prd:  the crews said the issues the united were from partly out of the united side of the united . <SEP>
# | b_prd:  <GO> emergency crews <GO> some of the passengers were thrown partly out at the open side of the said .
#
#
# step:  8160 | time: 69.46 | loss: 1.268
# | tgt:  <GO> two kids from michigan are in today 's third round . <SEP>
# | f_prd:  the years in the spent being the 's third round . <SEP>
# | b_prd:  <GO> two kids from , compete in today the third <NUM> .
#
#
# step:  8240 | time: 69.08 | loss: 1.113
# | tgt:  <GO> <quote> with the exception of march <NUM> , growth in business activity has been reported by ism members every month beginning with february <NUM> , <quote> the arizona-based group said . <SEP>
# | f_prd:  the we the first of the <NUM> , <NUM> and the activity was been killed by ism members every month beginning with february <NUM> , <NUM> the arizona-based group said . <SEP>
# | b_prd:  <GO> trip with the exception since march <NUM> , growth of business activity has been reported by ism members every month beginning of february future , <quote> the arizona-based he said .
#
#
# step:  8320 | time: 75.24 | loss: 1.407
# | tgt:  <GO> oracle 's offer <quote> undervalues the company and is not in the best interest of stockholders , <quote> peoplesoft ceo craig conway said . <SEP>
# | f_prd:  the 's aides undervalues undervalues the procedure 's eventually not feeling the world authority of the , <quote> said said craig conway told . <SEP>
# | b_prd:  <GO> oracle <quote> , offer undervalues the company it is suspect of the best interest into stockholders , <quote> <quote> ceo craig he said .
#
#
# step:  8400 | time: 80.47 | loss: 1.235
# | tgt:  <GO> for more than a century , an undetermined amount of money was lost , stolen , or never collected . <SEP>
# | f_prd:  the the than <NUM> dozen , the untold amount of the on lost , stolen or or never collected . <SEP>
# | b_prd:  <GO> <GO> more than a century , an undetermined amount the body was people , stolen stolen or never <NUM> .
#
#
# step:  8480 | time: 86.42 | loss: 1.323
# | tgt:  <GO> as a result , nelson now faces up to <NUM> years ' jail instead of life . <SEP>
# | f_prd:  the of month , the of faces up to the years in jail instead of life . <SEP>
# | b_prd:  <GO> as a result , nelson nelson faces up to <NUM> years about jail north of said .
#
#
# step:  8560 | time: 77.20 | loss: 1.216
# | tgt:  <GO> the dow jones industrial average .dji jumped <NUM> percent , while the standard & poor 's <NUM> index .spx leapt <NUM> percent . <SEP>
# | f_prd:  the technology-laced jones industrial average .dji rose <NUM> points , or the day & poor 's <NUM> index .spx leapt <NUM> percent . <SEP>
# | b_prd:  <GO> the dow jones industrial average index or <NUM> percent , while the standard & poor 's <NUM> index .spx to <NUM> said .
#
#
# step:  8640 | time: 78.68 | loss: 1.017
# | tgt:  <GO> arguing that the case was an isolated example , canada has threatened a trade backlash if tokyo 's ban is not justified on scientific grounds . <SEP>
# | f_prd:  the that the woman marks also isolated example , a , threatened a trade backlash if tokyo 's ban is not justified on scientific grounds . <SEP>
# | b_prd:  <GO> arguing <GO> the he was an isolated example , , has threatened a trade backlash if tokyo 's ban is not justified on scientific <NUM> .
#
#
# step:  8720 | time: 82.93 | loss: 1.146
# | tgt:  <GO> axelrod died of heart failure while asleep at his los angeles home , said his daughter , nina axelrod . <SEP>
# | f_prd:  the died and his failure to asleep at his los angeles home , and his daughter , nina axelrod . <SEP>
# | b_prd:  <GO> axelrod died of heart failure while asleep at his los angeles failure , with his daughter , nina said .
#
#
# step:  8800 | time: 94.62 | loss: 1.153
# | tgt:  <GO> <quote> fewer than <NUM> <quote> fbi offices have conducted investigations involving visits to mosques , the justice department said . <SEP>
# | f_prd:  the i than <NUM> people <NUM> offices have been investigations , visits to mosques , the company department said . <SEP>
# | b_prd:  <GO> <GO> more than , <quote> fbi offices have conducted investigations involving visits to mosques , the meteorology he <NUM> .
#
#
# step:  8880 | time: 103.77 | loss: 1.066
# | tgt:  <GO> stanford ( <NUM>- ) has a team full of such players this season . <SEP>
# | f_prd:  the slover who ) said not prison full of the players <quote> season . <SEP>
# | b_prd:  <GO> stanford ( <NUM>- ) in a team operators of such players earnings <NUM> .
#
#
# step:  8960 | time: 97.57 | loss: 1.159
# | tgt:  <GO> the people who are sending these messages are infringing on my rights and everyone else 's rights to use your computer , <quote> mckechnie said . <SEP>
# | f_prd:  the dow of feel sending these messages are infringing on my rights and everyone else 's rights to use your computer , <quote> mckechnie said . <SEP>
# | b_prd:  <GO> the people who are sending these messages are infringing on my rights and everyone else 's rights to use your disaster , <quote> he said .
#
#
# step:  9040 | time: 105.14 | loss: 1.023
# | tgt:  <GO> the bush administration wants the measure approved by june <NUM> , when the existing oil-for-food program is up for renewal . <SEP>
# | f_prd:  the technology-laced administration has the measure approved by the <NUM> , <NUM> the existing oil-for-food program , not to renewal . <SEP>
# | b_prd:  <GO> the bush administration wants the measure approved ended june <NUM> , claiming the existing oil-for-food who , percent for <NUM> .
#
#
# step:  9120 | time: 71.23 | loss: 1.152
# | tgt:  <GO> the industry censor forbade the sexual innuendo of the play and would not allow ewell 's character to sleep with monroe 's . <SEP>
# | f_prd:  the broader censor forbade the <NUM> innuendo of the semiconductor and had not allow ewell 's character to sleep with monroe 's customer <SEP>
# | b_prd:  <GO> the industry censor forbade the sexual innuendo is the play and would not allow ewell 's character to sleep with it said .
#
#
# step:  9200 | time: 69.92 | loss: 1.140
# | tgt:  <GO> ruffner , <NUM> , doesn 't yet have an attorney in the murder charge , authorities said . <SEP>
# | f_prd:  the , <NUM> , was 't begin have a immediate , <NUM> murder charge , authorities said . <SEP>
# | b_prd:  <GO> ruffner , <NUM> , doesn their yet as a <NUM> for the murder charge , he <NUM> .
#
#
# step:  9280 | time: 102.81 | loss: 0.954
# | tgt:  <GO> the plant plans to shut down its first shift and parts of the second shift monday to accommodate the president 's appearance , crosby said . <SEP>
# | f_prd:  the dow 's to shut down its open shift and parts of the second shift , to accommodate the second 's appearance , crosby said . <SEP>
# | b_prd:  <GO> the plant plans would shut in its first shift and parts in the second shift monday to accommodate the president 's appearance , he said .
#
#
# step:  9360 | time: 69.96 | loss: 1.097
# | tgt:  <GO> telemarketing associates , hired by vietnow , raised $ <NUM> million from <NUM> to <NUM> . <SEP>
# | f_prd:  the associates , hired by vietnow , raised its <NUM> million , $ . <NUM> . <SEP>
# | b_prd:  <GO> telemarketing associates , hired by vietnow , of $ <NUM> slipped from , to <NUM> .
#
#
# step:  9440 | time: 69.31 | loss: 0.961
# | tgt:  <GO> the transaction will grant handspring stockholders <NUM> of a share of palm--and no shares of palmsource--for each share of handspring common stock . <SEP>
# | f_prd:  the blue-chip will expand handspring stockholders and and a share of palm--and they shares of palmsource--for u.s. share of handspring common stock share <SEP>
# | b_prd:  <GO> the transaction will grant handspring stockholders <NUM> of a share of palm--and no shares of for each share of lendingtree common <NUM> .
#
#
# step:  9520 | time: 67.99 | loss: 0.944
# | tgt:  <GO> it is the first <quote> critical <quote> flaw discovered and fixed in the new windows server <NUM> . <SEP>
# | f_prd:  the is the first time that <quote> flaw discovered and fixed in the past york server <NUM> . <SEP>
# | b_prd:  <GO> it is the <GO> <quote> critical <quote> flaw discovered and fixed in the new windows to <NUM> .
#
#
# step:  9600 | time: 70.91 | loss: 0.994
# | tgt:  <GO> bob hope , master of the one-liner and americas favourite comedian , died with a smile on his face yesterday just months after celebrating his 100th birthday . <SEP>
# | f_prd:  the hope , the of the one-liner and americas favourite comedian , did in the smile on his wife without . <quote> in celebrating his 100th birthday . <SEP>
# | b_prd:  <GO> bob hope , master of the one-liner and americas favourite comedian , died with a smile on his face 's just airport after celebrating his 100th said .
#
#
# step:  9680 | time: 69.64 | loss: 0.998
# | tgt:  <GO> john logsdon , a board member , said that <quote> human spaceflight had become a place where dissent was not welcome . <quote> <SEP>
# | f_prd:  the clare , a spokesman member , said the while human spaceflight had become a place where dissent was not welcome . <quote> <SEP>
# | b_prd:  <GO> john logsdon , a board member , said that <quote> human spaceflight had become a place where dissent was not this . .
#
#
# step:  9760 | time: 69.52 | loss: 0.951
# | tgt:  <GO> in <NUM> a california state senator proposed a law requiring motorists over the age of <NUM> to take driving tests to renew their licenses . <SEP>
# | f_prd:  the <NUM> , california rate senator proposed a new requiring motorists over the age of <NUM> to <NUM> driving tests to renew their licenses . <SEP>
# | b_prd:  <GO> in <NUM> a california state senator proposed a law requiring motorists over the age october - to take driving tests to renew their <NUM> .
#
#
# step:  9840 | time: 68.67 | loss: 0.991
# | tgt:  <GO> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - escaped without injury , aaron said . <SEP>
# | f_prd:  the dow victim people in the building , <NUM> visitors and <NUM> employees , including harrison 's ex-girlfriend , escaped unharmed injury , aaron said . <SEP>
# | b_prd:  <GO> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - escaped without unharmed don he <NUM> .
#
#
# step:  9920 | time: 274.09 | loss: 1.130
# | tgt:  <GO> graham acknowledged that surgery was not exactly the way to begin a campaign , but he said he feels strong and has the go-ahead from his doctors . <SEP>
# | f_prd:  the acknowledged that the adds not exactly the way to begin a campaign , but he said . feels that and police been go-ahead from the job . <SEP>
# | b_prd:  <GO> graham acknowledged that surgery was not exactly the way to begin a ago , but he said he feels strong and by the go-ahead from 's said .
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# [array([[[ 1.86062902e-01,  2.10148826e-01,  2.04734251e-01, ...,
#          -2.66202807e-01,  1.69759989e-01,  1.71546802e-01],
#         [ 3.63038003e-01,  2.45954096e-01,  1.96831867e-01, ...,
#           4.84640896e-01, -1.30900949e-01, -1.64595842e-01],
#         [ 3.81635815e-01, -8.66772979e-02,  1.28202930e-01, ...,
#           1.06411435e-01,  2.22848654e-01, -1.17161430e-01],
#         ...,
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04]],
#
#        [[ 1.86062902e-01,  2.10148826e-01,  2.04734251e-01, ...,
#           7.82375216e-01,  2.29533494e-01,  3.88705641e-01],
#         [-4.37090874e-01, -2.99507260e-01, -7.73119330e-01, ...,
#          -2.12689668e-01,  1.19204104e-01, -1.61463857e-01],
#         [-2.30512559e-01,  5.41116953e-01, -5.13087213e-02, ...,
#           1.05889630e+00,  1.24115730e-02, -7.46808231e-01],
#         ...,
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04]],
#
#        [[ 1.86062902e-01,  2.10148826e-01,  2.04734251e-01, ...,
#          -1.42532974e-01,  4.65519540e-02,  1.82762854e-02],
#         [ 2.37335693e-02, -1.96819276e-01,  2.07895059e-02, ...,
#           4.34566177e-02,  1.61485687e-01,  4.82142121e-01],
#         [-2.45148301e-01, -4.15170044e-01, -1.32692635e-01, ...,
#           2.91527938e-02, -2.45019540e-01, -1.29378408e-01],
#         ...,
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04]],
#
#        [[ 1.86062902e-01,  2.10148826e-01,  2.04734251e-01, ...,
#           2.48253778e-01, -3.43628705e-01, -9.60689411e-02],
#         [ 2.37335693e-02, -1.96819276e-01,  2.07895059e-02, ...,
#           1.71887934e-01, -1.47628948e-01,  1.25681227e-02],
#         [ 1.27879484e-02, -5.62316537e-01, -5.38384736e-01, ...,
#           2.15762511e-01, -7.23258555e-02, -2.12221622e-01],
#         ...,
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04],
#         [ 5.21036389e-04, -2.50937446e-04, -1.63895616e-04, ...,
#           7.88284349e-04,  1.30069104e-03, -3.52681091e-04]]],
#       dtype=float32), array([[[-4.48813051e-04,  7.59719968e-01, -7.59555161e-01, ...,
#           8.18375032e-03,  2.94770896e-02,  2.34552135e-06],
#         [-6.88277662e-01,  2.05638818e-03, -9.63639975e-01, ...,
#           1.50516987e-01,  1.52003959e-01,  6.72477067e-01],
#         [-2.92273089e-02, -1.40071465e-02, -9.45719481e-01, ...,
#           3.29004616e-01,  9.99997556e-01,  2.59917397e-02],
#         ...,
#         [-6.85960114e-01, -3.73759569e-04, -8.62902641e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-6.85960114e-01, -3.73759569e-04, -8.62902641e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-6.85960114e-01, -3.73759569e-04, -8.62902641e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.48813051e-04,  7.59719968e-01, -7.59555161e-01, ...,
#           9.80536580e-01,  2.93354034e-01,  9.99791503e-01],
#         [-2.31003924e-06,  7.57776737e-01, -9.82764541e-05, ...,
#           8.99748970e-03,  6.89883173e-01,  3.92593756e-05],
#         [-9.55794811e-01,  3.06606889e-05, -5.29885702e-02, ...,
#           8.45064790e-07,  8.45104514e-05,  6.07340538e-04],
#         ...,
#         [-4.90111738e-01, -3.66432563e-04, -9.51918781e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-4.90111738e-01, -3.66432563e-04, -9.51918781e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-4.90111738e-01, -3.66432563e-04, -9.51918781e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.48813051e-04,  7.59719968e-01, -7.59555161e-01, ...,
#           8.58737230e-01,  4.42066252e-01,  7.21998930e-01],
#         [-7.61656523e-01,  5.58108032e-01, -1.59127172e-04, ...,
#           9.94905889e-01,  9.88636494e-01,  8.63409698e-01],
#         [-9.63512778e-01,  7.36530244e-01, -1.13549135e-07, ...,
#           6.49161302e-05,  2.82551866e-08,  1.06888113e-03],
#         ...,
#         [-7.66682804e-01, -2.35844593e-04, -9.44786370e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-7.66682804e-01, -2.35844593e-04, -9.44786370e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-7.66682804e-01, -2.35844593e-04, -9.44786370e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.48813051e-04,  7.59719968e-01, -7.59555161e-01, ...,
#           5.67501783e-02,  5.34155276e-07, -3.61669093e-01],
#         [-7.61656523e-01,  5.58108032e-01, -1.59127172e-04, ...,
#           7.06375402e-04,  3.92816544e-01,  7.20019394e-04],
#         [-1.04285395e-02,  7.36526310e-01, -9.94827688e-01, ...,
#           1.98660395e-03,  7.14632347e-02,  6.38781395e-03],
#         ...,
#         [-8.99962068e-01, -4.32651344e-04, -8.83724928e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-8.99962068e-01, -4.32651344e-04, -8.83724928e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-8.99962068e-01, -4.32651344e-04, -8.83724928e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32), array([[[-9.12206966e-15, -6.87283464e-05, -3.74864798e-13, ...,
#          -1.99835500e-04,  9.35943137e-16,  7.61594176e-01],
#         [-9.12875359e-15, -1.08980194e-01, -1.63680514e-10, ...,
#          -6.94719315e-01,  2.42680791e-04,  1.68838222e-02],
#         [-1.02925548e-14, -1.67844191e-05, -1.63958305e-10, ...,
#           1.33579507e-01,  3.74884997e-03,  1.70910021e-03],
#         ...,
#         [-9.63141441e-01, -3.45926383e-04, -5.10948062e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-9.63141441e-01, -3.45926383e-04, -5.10948062e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-9.63141441e-01, -3.45926383e-04, -5.10948062e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-9.12206966e-15, -6.87283464e-05, -3.74864798e-13, ...,
#          -7.61563838e-01,  9.91810793e-06,  3.96025646e-03],
#         [-5.60794069e-05, -3.77505245e-07, -7.61499524e-01, ...,
#          -1.88019911e-07,  8.29013594e-11,  7.61594176e-01],
#         [-5.60909430e-05, -1.72086991e-02, -7.61592269e-01, ...,
#           3.97335030e-02,  1.61776498e-01,  2.83618807e-03],
#         ...,
#         [-5.52432775e-01, -1.18006517e-06, -9.99805748e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-5.52432775e-01, -1.18006517e-06, -9.99805748e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-5.52432775e-01, -1.18006517e-06, -9.99805748e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-9.12206966e-15, -6.87283464e-05, -3.74864798e-13, ...,
#          -7.61597216e-01,  3.19533981e-02,  7.00864136e-01],
#         [-9.12275914e-15, -3.32085292e-05, -5.76509673e-11, ...,
#          -7.61593878e-01,  1.48962485e-07,  7.61594057e-01],
#         [-1.91014649e-09, -1.14639231e-03, -1.03466562e-03, ...,
#          -7.57881999e-01,  9.99999285e-01,  1.96950465e-01],
#         ...,
#         [-3.31309289e-01, -1.31150309e-05, -7.48698926e-03, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-3.31309289e-01, -1.31150309e-05, -7.48698926e-03, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-3.31309289e-01, -1.31150309e-05, -7.48698926e-03, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-9.12206966e-15, -6.87283464e-05, -3.74864798e-13, ...,
#          -7.61450589e-01,  4.40431586e-06,  7.08783388e-01],
#         [-9.12275914e-15, -3.32085292e-05, -5.76509673e-11, ...,
#           4.87916738e-01,  5.05494199e-06,  7.61939883e-01],
#         [-4.20110509e-11, -2.53052235e-07, -1.01684518e-05, ...,
#           4.64446843e-01,  2.82561832e-05,  9.40225124e-02],
#         ...,
#         [-9.63748693e-01, -1.14435221e-04, -4.55073148e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-9.63748693e-01, -1.14435221e-04, -4.55073148e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-9.63748693e-01, -1.14435221e-04, -4.55073148e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32)]
