# %% [markdown]
# # 作業: RNN 可以做什麼？

# %% [markdown]
# ## [作業目標]
# 瞭解目前 RNN 的應用領域

# %% [markdown]
# ## [作業重點]
# 查詢 RNN 的應用，瞭解 RNN 可以做些什麼事，瞭解一下涉及的領域應用背景

# %% [markdown]
# 瞭解三大深度學習網路的差異後，在課程內容提到的的下列應用：
#
# 1. 正負電影評價識別
# 2. 真假新聞的識別。
# 3. 語言翻譯
# 4. 文章生成
# 5. 聊天機器人
# 6. 股價預測
#
# 請學員網路查查除了有沒有其他更有用、有趣的 RNN 應用?
#
#
# 語音識別
#
# 生成圖像描述
#
# 視頻標記
#
# 時間序列瑕疵檢測
#
# 樂曲生成
#
# 語音合成
#
# 手寫辨識
#
# 人類動作識別
#
# 蛋白質同源偵測
